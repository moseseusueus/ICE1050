# %% [markdown]
# # Precisamos de Pandas?
# > Não necesariamente. Depende do problema pode trabalhar diretamente com arrays de NumPy. Mas as vezes Pandas pode ajudar muito a organizar os dados.
# https://pandas.pydata.org/docs/
# https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html

# %% [markdown]
# # Pandas
# > Módulo para trabalhar com **dados tabulares** (dados que faz sentido representar em uma tabela)
# - Principais objetos: `DataFrame`, `Series` e `Index`.
# - Permite criar tabelas como se fossem arrays de NumPy mas com rótulos pra linhas e colunas.
#     - A diferença de um array, cada coluna pode ter tipo de dados diferente.
# - Ferramentas poderosas para combinar e explorar conjuntos de dados (parecido a databases).
# - Jeitos para tolerar dados faltantes (missing data).

# %%
import numpy as np
import pandas as pd

print(pd.__version__)
# Out:
# 1.2.5

# %% [markdown]
# ## `DataFrame`
# > A principal estrutura de dados do Pandas.
#
# **Two-dimensional array** with both **flexible row indices** and **flexible column names** and **data types**.

# %%
# Criando DataFrames manualmente
df = pd.DataFrame(data=np.random.rand(3, 2),
             columns=['algo', 'otra cosa'],
             index=['dato A', 'dato B', 'dato C'])
display(df)
print(type(df))
print(df.shape)
# Out:
#             algo  otra cosa
# dato A  0.853306   0.948402
# dato B  0.777956   0.912157
# dato C  0.054502   0.576002
# <class 'pandas.core.frame.DataFrame'>
# (3, 2)

# %%
# Criando a partir da importação de dados (o mais comum)
data = pd.read_csv('bmi_world.csv')   # csv = "Comma-Separated Values"
display(data)
# Out:
#       Country/Region/World  ISO    Sex  Year   Mean BMI  \
# 0              Afghanistan  AFG    Men  1975  15.045565
# 1              Afghanistan  AFG    Men  1976  15.084892
# 2              Afghanistan  AFG    Men  1977  15.123787
# 3              Afghanistan  AFG    Men  1978  15.162724
# 4              Afghanistan  AFG    Men  1979  15.202452
# ...                    ...  ...    ...   ...        ...
# 16795             Zimbabwe  ZWE  Women  2012  18.397532
# 16796             Zimbabwe  ZWE  Women  2013  18.403608
# 16797             Zimbabwe  ZWE  Women  2014  18.412239
# 16798             Zimbabwe  ZWE  Women  2015  18.422837
# 16799             Zimbabwe  ZWE  Women  2016  18.433654
#
#        Mean BMI lower 95% uncertainty interval  \
# 0                                    12.512560
# 1                                    12.634216
# 2                                    12.755636
# 3                                    12.874059
# 4                                    12.981646
# ...                                        ...
# 16795                                17.523243
# 16796                                17.527503
# 16797                                17.528672
# 16798                                17.526655
# 16799                                17.512160
#
#        Mean BMI upper 95% uncertainty interval  \
# 0                                    17.552854
# 1                                    17.534976
# 2                                    17.502263
# 3                                    17.470846
# 4                                    17.462874
# ...                                        ...
# 16795                                19.282932
# 16796                                19.300005
# 16797                                19.308319
# 16798                                19.319873
# 16799                                19.359993
#
#        Prevalence of BMI>2SD (obesity)  \
# 0                             0.000517
# 1                             0.000560
# 2                             0.000611
# 3                             0.000671
# 4                             0.000740
# ...                                ...
# 16795                         0.047494
# 16796                         0.051572
# 16797                         0.055903
# 16798                         0.060503
# 16799                         0.065392
#
#        Prevalence of BMI>2SD lower 95% uncertainty interval  \
# 0                                               0.000003
# 1                                               0.000004
# 2                                               0.000006
# 3                                               0.000008
# 4                                               0.000010
# ...                                                  ...
# 16795                                           0.016632
# 16796                                           0.017634
# 16797                                           0.018745
# 16798                                           0.019798
# 16799                                           0.020502
#
#        Prevalence of BMI>2SD upper 95% uncertainty interval  ...  \
# 0                                               0.003211     ...
# 1                                               0.003240     ...
# 2                                               0.003540     ...
# 3                                               0.003754     ...
# 4                                               0.004005     ...
# ...                                                  ...     ...
# 16795                                           0.100410     ...
# 16796                                           0.109708     ...
# 16797                                           0.119722     ...
# 16798                                           0.130000     ...
# 16799                                           0.142068     ...
#
#        Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# 0                                               0.452694
# 1                                               0.451834
# 2                                               0.451514
# 3                                               0.450514
# 4                                               0.448919
# ...                                                  ...
# 16795                                           0.710953
# 16796                                           0.710982
# 16797                                           0.711459
# 16798                                           0.711302
# 16799                                           0.712524
#
#        Prevalence of minus2SD<BMI<minus1SD  \
# 0                                 0.382075
# 1                                 0.380632
# 2                                 0.379172
# 3                                 0.377684
# 4                                 0.376138
# ...                                    ...
# 16795                             0.147573
# 16796                             0.143132
# 16797                             0.138744
# 16798                             0.134411
# 16799                             0.130116
#
#        Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# 0                                               0.240744
# 1                                               0.243738
# 2                                               0.245647
# 3                                               0.247541
# 4                                               0.249439
# ...                                                  ...
# 16795                                           0.098637
# 16796                                           0.092936
# 16797                                           0.087909
# 16798                                           0.081897
# 16799                                           0.076494
#
#        Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# 0                                               0.548096
# 1                                               0.542044
# 2                                               0.535515
# 3                                               0.528804
# 4                                               0.523514
# ...                                                  ...
# 16795                                           0.201325
# 16796                                           0.198523
# 16797                                           0.195503
# 16798                                           0.193685
# 16799                                           0.192211
#
#        Prevalence of BMI<minus1SD (underweight)  \
# 0                                      0.701622
# 1                                      0.698587
# 2                                      0.695497
# 3                                      0.692353
# 4                                      0.689128
# ...                                         ...
# 16795                                  0.172943
# 16796                                  0.166850
# 16797                                  0.160923
# 16798                                  0.155169
# 16799                                  0.149565
#
#        Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# 0                                               0.543184
# 1                                               0.544105
# 2                                               0.544872
# 3                                               0.544228
# 4                                               0.544682
# ...                                                  ...
# 16795                                           0.120780
# 16796                                           0.113879
# 16797                                           0.106772
# 16798                                           0.099421
# 16799                                           0.092851
#
#        Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# 0                                               0.845123
# 1                                               0.837919
# 2                                               0.831829
# 3                                               0.826128
# 4                                               0.819239
# ...                                                  ...
# 16795                                           0.231131
# 16796                                           0.227143
# 16797                                           0.221977
# 16798                                           0.218065
# 16799                                           0.216192
#
#        Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# 0                                               0.319547
# 1                                               0.317956
# 2                                               0.316325
# 3                                               0.314669
# 4                                               0.312990
# ...                                                  ...
# 16795                                           0.025371
# 16796                                           0.023718
# 16797                                           0.022179
# 16798                                           0.020758
# 16799                                           0.019449
#
#        Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# 0                                               0.134384
# 1                                               0.137219
# 2                                               0.140390
# 3                                               0.141116
# 4                                               0.144076
# ...                                                  ...
# 16795                                           0.008529
# 16796                                           0.007467
# 16797                                           0.006387
# 16798                                           0.005504
# 16799                                           0.004590
#
#        Prevalence of BMI<minus2SD upper 95% uncertainty interval
# 0                                               0.498794
# 1                                               0.492346
# 2                                               0.486938
# 3                                               0.482551
# 4                                               0.477112
# ...                                                  ...
# 16795                                           0.053849
# 16796                                           0.051700
# 16797                                           0.049882
# 16798                                           0.048322
# 16799                                           0.047662
#
# [16800 rows x 28 columns]

# %% [markdown]
# ## As partes de um DataFrame
# Mais uma vez, todas são objetos com propriedades e métodos.
# ![dataframe.png](dataframe.png)
# - Os rótulos de linhas e os de colunas estão em objetos de tipo `index` (o das colunas seria tipo o index do axis 1)
# - Os valores dos dados estão dentro de **arrays de NumPy** (`ndarray`)
# - Column names ou labels é a mesma coisa
# - Cada coluna pode ter um **tipo de dados diferente**

# %% [markdown]
# ### Os dados

# %%
# Os tipos de dados de cada coluna
data.dtypes

# Nota: 'object' é um coringa no qual cada elemento pode ser um objeto diferente.
# Os strings por default vão para object. Mas pode ver https://pandas.pydata.org/pandas-docs/version/1.4/user_guide/text.html
# Out:
# Country/Region/World                                                   object
# ISO                                                                    object
# Sex                                                                    object
# Year                                                                    int64
# Mean BMI                                                              float64
# Mean BMI lower 95% uncertainty interval                               float64
# Mean BMI upper 95% uncertainty interval                               float64
# Prevalence of BMI>2SD (obesity)                                       float64
# Prevalence of BMI>2SD lower 95% uncertainty interval                  float64
# Prevalence of BMI>2SD upper 95% uncertainty interval                  float64
# Prevalence of BMI>1SD (overweight)                                    float64
# Prevalence of BMI>1SD lower 95% uncertainty interval                  float64
# Prevalence of BMI>1SD upper 95% uncertainty interval                  float64
# Prevalence of 1SD<BMI<2SD                                             float64
# Prevalence of 1SD<BMI<2SD lower 95% uncertainty interval              float64
# Prevalence of 1SD<BMI<2SD upper 95% uncertainty interval              float64
# Prevalence of minus1SD<BMI<1SD                                        float64
# Prevalence of minus1SD<BMI<1SD lower 95% uncertainty interval         float64
# Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval         float64
# Prevalence of minus2SD<BMI<minus1SD                                   float64
# Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval    float64
# Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval    float64
# Prevalence of BMI<minus1SD (underweight)                              float64
# Prevalence of BMI<minus1SD lower 95% uncertainty interval             float64
# Prevalence of BMI<minus1SD upper 95% uncertainty interval             float64
# Prevalence of BMI<minus2SD (moderate & severe underweight)            float64
# Prevalence of BMI<minus2SD lower 95% uncertainty interval             float64
# Prevalence of BMI<minus2SD upper 95% uncertainty interval             float64
# dtype: object

# %%
# Especificando tipos de dados na hora de importar uma tabela
data = pd.read_csv('bmi_world.csv', dtype={'Year':np.int16})
data.dtypes
# Out:
# Country/Region/World                                                   object
# ISO                                                                    object
# Sex                                                                    object
# Year                                                                    int16
# Mean BMI                                                              float64
# Mean BMI lower 95% uncertainty interval                               float64
# Mean BMI upper 95% uncertainty interval                               float64
# Prevalence of BMI>2SD (obesity)                                       float64
# Prevalence of BMI>2SD lower 95% uncertainty interval                  float64
# Prevalence of BMI>2SD upper 95% uncertainty interval                  float64
# Prevalence of BMI>1SD (overweight)                                    float64
# Prevalence of BMI>1SD lower 95% uncertainty interval                  float64
# Prevalence of BMI>1SD upper 95% uncertainty interval                  float64
# Prevalence of 1SD<BMI<2SD                                             float64
# Prevalence of 1SD<BMI<2SD lower 95% uncertainty interval              float64
# Prevalence of 1SD<BMI<2SD upper 95% uncertainty interval              float64
# Prevalence of minus1SD<BMI<1SD                                        float64
# Prevalence of minus1SD<BMI<1SD lower 95% uncertainty interval         float64
# Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval         float64
# Prevalence of minus2SD<BMI<minus1SD                                   float64
# Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval    float64
# Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval    float64
# Prevalence of BMI<minus1SD (underweight)                              float64
# Prevalence of BMI<minus1SD lower 95% uncertainty interval             float64
# Prevalence of BMI<minus1SD upper 95% uncertainty interval             float64
# Prevalence of BMI<minus2SD (moderate & severe underweight)            float64
# Prevalence of BMI<minus2SD lower 95% uncertainty interval             float64
# Prevalence of BMI<minus2SD upper 95% uncertainty interval             float64
# dtype: object

# %%
# Modificando tipos de dados de um DataFrame existente
data = data.astype({'Mean BMI':int, 'Year':'string'})
data.dtypes
# Out:
# Country/Region/World                                                   object
# ISO                                                                    object
# Sex                                                                    object
# Year                                                                   string
# Mean BMI                                                                int64
# Mean BMI lower 95% uncertainty interval                               float64
# Mean BMI upper 95% uncertainty interval                               float64
# Prevalence of BMI>2SD (obesity)                                       float64
# Prevalence of BMI>2SD lower 95% uncertainty interval                  float64
# Prevalence of BMI>2SD upper 95% uncertainty interval                  float64
# Prevalence of BMI>1SD (overweight)                                    float64
# Prevalence of BMI>1SD lower 95% uncertainty interval                  float64
# Prevalence of BMI>1SD upper 95% uncertainty interval                  float64
# Prevalence of 1SD<BMI<2SD                                             float64
# Prevalence of 1SD<BMI<2SD lower 95% uncertainty interval              float64
# Prevalence of 1SD<BMI<2SD upper 95% uncertainty interval              float64
# Prevalence of minus1SD<BMI<1SD                                        float64
# Prevalence of minus1SD<BMI<1SD lower 95% uncertainty interval         float64
# Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval         float64
# Prevalence of minus2SD<BMI<minus1SD                                   float64
# Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval    float64
# Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval    float64
# Prevalence of BMI<minus1SD (underweight)                              float64
# Prevalence of BMI<minus1SD lower 95% uncertainty interval             float64
# Prevalence of BMI<minus1SD upper 95% uncertainty interval             float64
# Prevalence of BMI<minus2SD (moderate & severe underweight)            float64
# Prevalence of BMI<minus2SD lower 95% uncertainty interval             float64
# Prevalence of BMI<minus2SD upper 95% uncertainty interval             float64
# dtype: object

# %%
# Os valores podem ser 'extraidos' do DataFrame com .values em um array de NumPy
my_values = data.values
print( type(my_values) , my_values.dtype, my_values.shape)     # dtype=object !
print( my_values )
print( my_values[0:3, 0:5] )
# Out:
# <class 'numpy.ndarray'> object (16800, 28)
# [['Afghanistan' 'AFG' 'Men' ... 0.319546871462954 0.134383556440849
#   0.498794246921537]
#  ['Afghanistan' 'AFG' 'Men' ... 0.317955675685991 0.137219453925469
#   0.492346393006221]
#  ['Afghanistan' 'AFG' 'Men' ... 0.316325394256435 0.140390225037904
#   0.486938321190334]
#  ...
#  ['Zimbabwe' 'ZWE' 'Women' ... 0.022178850173093 0.0063874179754
#   0.049882167968896]
#  ['Zimbabwe' 'ZWE' 'Women' ... 0.020757858975416 0.005503585042544
#   0.048321629869164]
#  ['Zimbabwe' 'ZWE' 'Women' ... 0.019448696311476 0.004589730830114
#   0.047662088979896]]
# [['Afghanistan' 'AFG' 'Men' '1975' 15]
#  ['Afghanistan' 'AFG' 'Men' '1976' 15]
#  ['Afghanistan' 'AFG' 'Men' '1977' 15]]

# %% [markdown]
# ### Os index

# %%
# The row index
print( type(data.index) )
display( data.index )
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>
# RangeIndex(start=0, stop=16800, step=1)

# %%
# The column index
print( type(data.columns) )   # the column names
display( data.columns )
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['Country/Region/World', 'ISO', 'Sex', 'Year', 'Mean BMI',
#        'Mean BMI lower 95% uncertainty interval',
#        'Mean BMI upper 95% uncertainty interval',
#        'Prevalence of BMI>2SD (obesity)',
#        'Prevalence of BMI>2SD lower 95% uncertainty interval',
#        'Prevalence of BMI>2SD upper 95% uncertainty interval',
#        'Prevalence of BMI>1SD (overweight)',
#        'Prevalence of BMI>1SD lower 95% uncertainty interval',
#        'Prevalence of BMI>1SD upper 95% uncertainty interval',
#        'Prevalence of 1SD<BMI<2SD',
#        'Prevalence of 1SD<BMI<2SD lower 95% uncertainty interval',
#        'Prevalence of 1SD<BMI<2SD upper 95% uncertainty interval',
#        'Prevalence of minus1SD<BMI<1SD',
#        'Prevalence of minus1SD<BMI<1SD lower 95% uncertainty interval',
#        'Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval',
#        'Prevalence of minus2SD<BMI<minus1SD',
#        'Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval',
#        'Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval',
#        'Prevalence of BMI<minus1SD (underweight)',
#        'Prevalence of BMI<minus1SD lower 95% uncertainty interval',
#        'Prevalence of BMI<minus1SD upper 95% uncertainty interval',
#        'Prevalence of BMI<minus2SD (moderate & severe underweight)',
#        'Prevalence of BMI<minus2SD lower 95% uncertainty interval',
#        'Prevalence of BMI<minus2SD upper 95% uncertainty interval'],
#       dtype='object')

# %% [markdown]
# ## `Index`
# > - O objetivo dos index é facilitar a seleção de dados dentro da tabela.
# > - Existem diferentes tipos de index para escolher (uma família de objetos que funcionam como index)
# > https://pandas.pydata.org/pandas-docs/stable/reference/indexing.html
# > - Não é tão comum você diretamente criar um objeto de index, geralmente cria eles junto com o DataFrame. Mas se você quer controle mais fino pode ser útil criar o seu ou manipular as propriedades deles.

# %%
# Numeric index
ind = pd.RangeIndex(0, 1000, 10)    # RangeIndex é o padrão
print(ind)

# Date/time index
ind = pd.date_range(start='1/1/2020', end='29/09/2020')
print(ind)
# Out:
# RangeIndex(start=0, stop=1000, step=10)
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-09-20', '2020-09-21', '2020-09-22', '2020-09-23',
#                '2020-09-24', '2020-09-25', '2020-09-26', '2020-09-27',
#                '2020-09-28', '2020-09-29'],
#               dtype='datetime64[ns]', length=273, freq='D')

# %%
# Muito usado: definir qual coluna usar como index na hora de importar uma tabela
data = pd.read_csv('bmi_world.csv', index_col='Country/Region/World')
display(data)
display(data.index)
display(data.columns)
display(data.index.unique())
# Out:
#                       ISO    Sex  Year   Mean BMI  \
# Country/Region/World
# Afghanistan           AFG    Men  1975  15.045565
# Afghanistan           AFG    Men  1976  15.084892
# Afghanistan           AFG    Men  1977  15.123787
# Afghanistan           AFG    Men  1978  15.162724
# Afghanistan           AFG    Men  1979  15.202452
# ...                   ...    ...   ...        ...
# Zimbabwe              ZWE  Women  2012  18.397532
# Zimbabwe              ZWE  Women  2013  18.403608
# Zimbabwe              ZWE  Women  2014  18.412239
# Zimbabwe              ZWE  Women  2015  18.422837
# Zimbabwe              ZWE  Women  2016  18.433654
#
#                       Mean BMI lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         12.512560
# Afghanistan                                         12.634216
# Afghanistan                                         12.755636
# Afghanistan                                         12.874059
# Afghanistan                                         12.981646
# ...                                                       ...
# Zimbabwe                                            17.523243
# Zimbabwe                                            17.527503
# Zimbabwe                                            17.528672
# Zimbabwe                                            17.526655
# Zimbabwe                                            17.512160
#
#                       Mean BMI upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         17.552854
# Afghanistan                                         17.534976
# Afghanistan                                         17.502263
# Afghanistan                                         17.470846
# Afghanistan                                         17.462874
# ...                                                       ...
# Zimbabwe                                            19.282932
# Zimbabwe                                            19.300005
# Zimbabwe                                            19.308319
# Zimbabwe                                            19.319873
# Zimbabwe                                            19.359993
#
#                       Prevalence of BMI>2SD (obesity)  \
# Country/Region/World
# Afghanistan                                  0.000517
# Afghanistan                                  0.000560
# Afghanistan                                  0.000611
# Afghanistan                                  0.000671
# Afghanistan                                  0.000740
# ...                                               ...
# Zimbabwe                                     0.047494
# Zimbabwe                                     0.051572
# Zimbabwe                                     0.055903
# Zimbabwe                                     0.060503
# Zimbabwe                                     0.065392
#
#                       Prevalence of BMI>2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.000003
# Afghanistan                                                    0.000004
# Afghanistan                                                    0.000006
# Afghanistan                                                    0.000008
# Afghanistan                                                    0.000010
# ...                                                                 ...
# Zimbabwe                                                       0.016632
# Zimbabwe                                                       0.017634
# Zimbabwe                                                       0.018745
# Zimbabwe                                                       0.019798
# Zimbabwe                                                       0.020502
#
#                       Prevalence of BMI>2SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.003211
# Afghanistan                                                    0.003240
# Afghanistan                                                    0.003540
# Afghanistan                                                    0.003754
# Afghanistan                                                    0.004005
# ...                                                                 ...
# Zimbabwe                                                       0.100410
# Zimbabwe                                                       0.109708
# Zimbabwe                                                       0.119722
# Zimbabwe                                                       0.130000
# Zimbabwe                                                       0.142068
#
#                       Prevalence of BMI>1SD (overweight)  ...  \
# Country/Region/World                                      ...
# Afghanistan                                     0.003053  ...
# Afghanistan                                     0.003319  ...
# Afghanistan                                     0.003619  ...
# Afghanistan                                     0.003956  ...
# Afghanistan                                     0.004334  ...
# ...                                                  ...  ...
# Zimbabwe                                        0.185233  ...
# Zimbabwe                                        0.194297  ...
# Zimbabwe                                        0.203623  ...
# Zimbabwe                                        0.213235  ...
# Zimbabwe                                        0.223151  ...
#
#                       Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.452694
# Afghanistan                                                    0.451834
# Afghanistan                                                    0.451514
# Afghanistan                                                    0.450514
# Afghanistan                                                    0.448919
# ...                                                                 ...
# Zimbabwe                                                       0.710953
# Zimbabwe                                                       0.710982
# Zimbabwe                                                       0.711459
# Zimbabwe                                                       0.711302
# Zimbabwe                                                       0.712524
#
#                       Prevalence of minus2SD<BMI<minus1SD  \
# Country/Region/World
# Afghanistan                                      0.382075
# Afghanistan                                      0.380632
# Afghanistan                                      0.379172
# Afghanistan                                      0.377684
# Afghanistan                                      0.376138
# ...                                                   ...
# Zimbabwe                                         0.147573
# Zimbabwe                                         0.143132
# Zimbabwe                                         0.138744
# Zimbabwe                                         0.134411
# Zimbabwe                                         0.130116
#
#                       Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.240744
# Afghanistan                                                    0.243738
# Afghanistan                                                    0.245647
# Afghanistan                                                    0.247541
# Afghanistan                                                    0.249439
# ...                                                                 ...
# Zimbabwe                                                       0.098637
# Zimbabwe                                                       0.092936
# Zimbabwe                                                       0.087909
# Zimbabwe                                                       0.081897
# Zimbabwe                                                       0.076494
#
#                       Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.548096
# Afghanistan                                                    0.542044
# Afghanistan                                                    0.535515
# Afghanistan                                                    0.528804
# Afghanistan                                                    0.523514
# ...                                                                 ...
# Zimbabwe                                                       0.201325
# Zimbabwe                                                       0.198523
# Zimbabwe                                                       0.195503
# Zimbabwe                                                       0.193685
# Zimbabwe                                                       0.192211
#
#                       Prevalence of BMI<minus1SD (underweight)  \
# Country/Region/World
# Afghanistan                                           0.701622
# Afghanistan                                           0.698587
# Afghanistan                                           0.695497
# Afghanistan                                           0.692353
# Afghanistan                                           0.689128
# ...                                                        ...
# Zimbabwe                                              0.172943
# Zimbabwe                                              0.166850
# Zimbabwe                                              0.160923
# Zimbabwe                                              0.155169
# Zimbabwe                                              0.149565
#
#                       Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.543184
# Afghanistan                                                    0.544105
# Afghanistan                                                    0.544872
# Afghanistan                                                    0.544228
# Afghanistan                                                    0.544682
# ...                                                                 ...
# Zimbabwe                                                       0.120780
# Zimbabwe                                                       0.113879
# Zimbabwe                                                       0.106772
# Zimbabwe                                                       0.099421
# Zimbabwe                                                       0.092851
#
#                       Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.845123
# Afghanistan                                                    0.837919
# Afghanistan                                                    0.831829
# Afghanistan                                                    0.826128
# Afghanistan                                                    0.819239
# ...                                                                 ...
# Zimbabwe                                                       0.231131
# Zimbabwe                                                       0.227143
# Zimbabwe                                                       0.221977
# Zimbabwe                                                       0.218065
# Zimbabwe                                                       0.216192
#
#                       Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# Country/Region/World
# Afghanistan                                                    0.319547
# Afghanistan                                                    0.317956
# Afghanistan                                                    0.316325
# Afghanistan                                                    0.314669
# Afghanistan                                                    0.312990
# ...                                                                 ...
# Zimbabwe                                                       0.025371
# Zimbabwe                                                       0.023718
# Zimbabwe                                                       0.022179
# Zimbabwe                                                       0.020758
# Zimbabwe                                                       0.019449
#
#                       Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.134384
# Afghanistan                                                    0.137219
# Afghanistan                                                    0.140390
# Afghanistan                                                    0.141116
# Afghanistan                                                    0.144076
# ...                                                                 ...
# Zimbabwe                                                       0.008529
# Zimbabwe                                                       0.007467
# Zimbabwe                                                       0.006387
# Zimbabwe                                                       0.005504
# Zimbabwe                                                       0.004590
#
#                       Prevalence of BMI<minus2SD upper 95% uncertainty interval
# Country/Region/World
# Afghanistan                                                    0.498794
# Afghanistan                                                    0.492346
# Afghanistan                                                    0.486938
# Afghanistan                                                    0.482551
# Afghanistan                                                    0.477112
# ...                                                                 ...
# Zimbabwe                                                       0.053849
# Zimbabwe                                                       0.051700
# Zimbabwe                                                       0.049882
# Zimbabwe                                                       0.048322
# Zimbabwe                                                       0.047662
#
# [16800 rows x 27 columns]
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='Country/Region/World', length=16800)
# Index(['ISO', 'Sex', 'Year', 'Mean BMI',
#        'Mean BMI lower 95% uncertainty interval',
#        'Mean BMI upper 95% uncertainty interval',
#        'Prevalence of BMI>2SD (obesity)',
#        'Prevalence of BMI>2SD lower 95% uncertainty interval',
#        'Prevalence of BMI>2SD upper 95% uncertainty interval',
#        'Prevalence of BMI>1SD (overweight)',
#        'Prevalence of BMI>1SD lower 95% uncertainty interval',
#        'Prevalence of BMI>1SD upper 95% uncertainty interval',
#        'Prevalence of 1SD<BMI<2SD',
#        'Prevalence of 1SD<BMI<2SD lower 95% uncertainty interval',
#        'Prevalence of 1SD<BMI<2SD upper 95% uncertainty interval',
#        'Prevalence of minus1SD<BMI<1SD',
#        'Prevalence of minus1SD<BMI<1SD lower 95% uncertainty interval',
#        'Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval',
#        'Prevalence of minus2SD<BMI<minus1SD',
#        'Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval',
#        'Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval',
#        'Prevalence of BMI<minus1SD (underweight)',
#        'Prevalence of BMI<minus1SD lower 95% uncertainty interval',
#        'Prevalence of BMI<minus1SD upper 95% uncertainty interval',
#        'Prevalence of BMI<minus2SD (moderate & severe underweight)',
#        'Prevalence of BMI<minus2SD lower 95% uncertainty interval',
#        'Prevalence of BMI<minus2SD upper 95% uncertainty interval'],
#       dtype='object')
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'United Kingdom', 'United States of America', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Venezuela', 'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country/Region/World', length=200)

# %% [markdown]
# ## Selecting elements
# Existem vários jeitos de seleccionar partes do DataFrame e tem que ficar ligado para não cair em alguns erros.
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html
# https://pandas.pydata.org/docs/user_guide/indexing.html#indexing
# https://towardsdatascience.com/how-to-index-data-in-pandas-with-python-4437c24ff332

# %% [markdown]
# ### Usando só `[ ]`
# Os colchetes são um jeito simples, porém não tão versátil, de seleccionar **colunas** inteiras.

# %%
data2 = data[['Year','Mean BMI']]
display(data2)   # Pedindo com uma lista de nomes de colunas
type(data2)  # Devolve um DataFrame
# Out:
#                       Year   Mean BMI
# Country/Region/World
# Afghanistan           1975  15.045565
# Afghanistan           1976  15.084892
# Afghanistan           1977  15.123787
# Afghanistan           1978  15.162724
# Afghanistan           1979  15.202452
# ...                    ...        ...
# Zimbabwe              2012  18.397532
# Zimbabwe              2013  18.403608
# Zimbabwe              2014  18.412239
# Zimbabwe              2015  18.422837
# Zimbabwe              2016  18.433654
#
# [16800 rows x 2 columns]
# pandas.core.frame.DataFrame

# %%
data3 = data['Mean BMI']
display(data3)   # Pedindo só uma coluna
type(data3)    # Series: como se fosse um DataFrame de uma coluna só (depois vemos mais detalhe)
# Out:
# Country/Region/World
# Afghanistan    15.045565
# Afghanistan    15.084892
# Afghanistan    15.123787
# Afghanistan    15.162724
# Afghanistan    15.202452
#                  ...
# Zimbabwe       18.397532
# Zimbabwe       18.403608
# Zimbabwe       18.412239
# Zimbabwe       18.422837
# Zimbabwe       18.433654
# Name: Mean BMI, Length: 16800, dtype: float64
# pandas.core.series.Series

# %% [markdown]
# ### Usando location: `.loc[ rows ]` o `.loc[ rows , cols ]`
# - Seleccionar linhas (e colunas) pelo **valor** dos index
# - For both the part before and after the comma, you can use a single label, a list of labels, a slice of labels, a conditional expression or a colon (:). Using a colon specifies you want to select all rows or columns.
# - **You can assign new values to a selection based on loc/iloc.**

# %%
display( data.loc['Brazil'] )
# Out:
#                       ISO    Sex  Year   Mean BMI  \
# Country/Region/World
# Brazil                BRA    Men  1975  17.527834
# Brazil                BRA    Men  1976  17.571680
# Brazil                BRA    Men  1977  17.615716
# Brazil                BRA    Men  1978  17.660124
# Brazil                BRA    Men  1979  17.705389
# ...                   ...    ...   ...        ...
# Brazil                BRA  Women  2012  19.828358
# Brazil                BRA  Women  2013  19.922935
# Brazil                BRA  Women  2014  20.020112
# Brazil                BRA  Women  2015  20.118750
# Brazil                BRA  Women  2016  20.217418
#
#                       Mean BMI lower 95% uncertainty interval  \
# Country/Region/World
# Brazil                                              15.642907
# Brazil                                              15.864166
# Brazil                                              16.053136
# Brazil                                              16.251776
# Brazil                                              16.438387
# ...                                                       ...
# Brazil                                              19.527812
# Brazil                                              19.576157
# Brazil                                              19.612738
# Brazil                                              19.638321
# Brazil                                              19.659301
#
#                       Mean BMI upper 95% uncertainty interval  \
# Country/Region/World
# Brazil                                              19.369611
# Brazil                                              19.252332
# Brazil                                              19.159285
# Brazil                                              19.057076
# Brazil                                              18.953946
# ...                                                       ...
# Brazil                                              20.135074
# Brazil                                              20.272302
# Brazil                                              20.435908
# Brazil                                              20.607085
# Brazil                                              20.802129
#
#                       Prevalence of BMI>2SD (obesity)  \
# Country/Region/World
# Brazil                                       0.009289
# Brazil                                       0.009967
# Brazil                                       0.010722
# Brazil                                       0.011553
# Brazil                                       0.012467
# ...                                               ...
# Brazil                                       0.080640
# Brazil                                       0.083756
# Brazil                                       0.086964
# Brazil                                       0.090268
# Brazil                                       0.093676
#
#                       Prevalence of BMI>2SD lower 95% uncertainty interval  \
# Country/Region/World
# Brazil                                                         0.000567
# Brazil                                                         0.000753
# Brazil                                                         0.001006
# Brazil                                                         0.001327
# Brazil                                                         0.001722
# ...                                                                 ...
# Brazil                                                         0.050013
# Brazil                                                         0.050020
# Brazil                                                         0.049700
# Brazil                                                         0.048860
# Brazil                                                         0.047878
#
#                       Prevalence of BMI>2SD upper 95% uncertainty interval  \
# Country/Region/World
# Brazil                                                         0.036280
# Brazil                                                         0.036891
# Brazil                                                         0.037584
# Brazil                                                         0.037876
# Brazil                                                         0.038398
# ...                                                                 ...
# Brazil                                                         0.120256
# Brazil                                                         0.128477
# Brazil                                                         0.136199
# Brazil                                                         0.145350
# Brazil                                                         0.155652
#
#                       Prevalence of BMI>1SD (overweight)  ...  \
# Country/Region/World                                      ...
# Brazil                                          0.058622  ...
# Brazil                                          0.061856  ...
# Brazil                                          0.065287  ...
# Brazil                                          0.068895  ...
# Brazil                                          0.072679  ...
# ...                                                  ...  ...
# Brazil                                          0.246978  ...
# Brazil                                          0.251530  ...
# Brazil                                          0.256159  ...
# Brazil                                          0.260859  ...
# Brazil                                          0.265614  ...
#
#                       Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# Country/Region/World
# Brazil                                                         0.802708
# Brazil                                                         0.798860
# Brazil                                                         0.794978
# Brazil                                                         0.791150
# Brazil                                                         0.787476
# ...                                                                 ...
# Brazil                                                         0.662270
# Brazil                                                         0.662319
# Brazil                                                         0.662467
# Brazil                                                         0.662466
# Brazil                                                         0.663762
#
#                       Prevalence of minus2SD<BMI<minus1SD  \
# Country/Region/World
# Brazil                                           0.181669
# Brazil                                           0.179380
# Brazil                                           0.177106
# Brazil                                           0.174832
# Brazil                                           0.172588
# ...                                                   ...
# Brazil                                           0.117196
# Brazil                                           0.116854
# Brazil                                           0.116523
# Brazil                                           0.116205
# Brazil                                           0.115923
#
#                       Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Brazil                                                         0.100488
# Brazil                                                         0.101289
# Brazil                                                         0.102228
# Brazil                                                         0.103727
# Brazil                                                         0.104537
# ...                                                                 ...
# Brazil                                                         0.084187
# Brazil                                                         0.081938
# Brazil                                                         0.079970
# Brazil                                                         0.077428
# Brazil                                                         0.074787
#
#                       Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Brazil                                                         0.285020
# Brazil                                                         0.277195
# Brazil                                                         0.270142
# Brazil                                                         0.263108
# Brazil                                                         0.257104
# ...                                                                 ...
# Brazil                                                         0.155603
# Brazil                                                         0.157443
# Brazil                                                         0.159554
# Brazil                                                         0.162537
# Brazil                                                         0.165158
#
#                       Prevalence of BMI<minus1SD (underweight)  \
# Country/Region/World
# Brazil                                                0.241798
# Brazil                                                0.238026
# Brazil                                                0.234355
# Brazil                                                0.230780
# Brazil                                                0.227315
# ...                                                        ...
# Brazil                                                0.142060
# Brazil                                                0.141378
# Brazil                                                0.140739
# Brazil                                                0.140154
# Brazil                                                0.139647
#
#                       Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Brazil                                                         0.145466
# Brazil                                                         0.147142
# Brazil                                                         0.147721
# Brazil                                                         0.148224
# Brazil                                                         0.149020
# ...                                                                 ...
# Brazil                                                         0.105613
# Brazil                                                         0.103223
# Brazil                                                         0.100775
# Brazil                                                         0.097487
# Brazil                                                         0.094363
#
#                       Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Brazil                                                         0.361760
# Brazil                                                         0.351501
# Brazil                                                         0.341051
# Brazil                                                         0.331532
# Brazil                                                         0.321685
# ...                                                                 ...
# Brazil                                                         0.181797
# Brazil                                                         0.183863
# Brazil                                                         0.186078
# Brazil                                                         0.189159
# Brazil                                                         0.192433
#
#                       Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# Country/Region/World
# Brazil                                                         0.060129
# Brazil                                                         0.058646
# Brazil                                                         0.057249
# Brazil                                                         0.055948
# Brazil                                                         0.054727
# ...                                                                 ...
# Brazil                                                         0.024864
# Brazil                                                         0.024524
# Brazil                                                         0.024215
# Brazil                                                         0.023949
# Brazil                                                         0.023725
#
#                       Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# Country/Region/World
# Brazil                                                         0.013706
# Brazil                                                         0.014496
# Brazil                                                         0.015436
# Brazil                                                         0.016491
# Brazil                                                         0.017693
# ...                                                                 ...
# Brazil                                                         0.012868
# Brazil                                                         0.011934
# Brazil                                                         0.010707
# Brazil                                                         0.009579
# Brazil                                                         0.008690
#
#                       Prevalence of BMI<minus2SD upper 95% uncertainty interval
# Country/Region/World
# Brazil                                                         0.147486
# Brazil                                                         0.139865
# Brazil                                                         0.131982
# Brazil                                                         0.126350
# Brazil                                                         0.119729
# ...                                                                 ...
# Brazil                                                         0.041535
# Brazil                                                         0.042458
# Brazil                                                         0.043755
# Brazil                                                         0.044973
# Brazil                                                         0.046769
#
# [84 rows x 27 columns]

# %%
tabela2 = data.loc['Brazil', ['Year','Mean BMI'] ]  # row index value, column index values (name)
display( tabela2 )
# Out:
#                       Year   Mean BMI
# Country/Region/World
# Brazil                1975  17.527834
# Brazil                1976  17.571680
# Brazil                1977  17.615716
# Brazil                1978  17.660124
# Brazil                1979  17.705389
# ...                    ...        ...
# Brazil                2012  19.828358
# Brazil                2013  19.922935
# Brazil                2014  20.020112
# Brazil                2015  20.118750
# Brazil                2016  20.217418
#
# [84 rows x 2 columns]

# %%
display( data.loc['Brazil', 'Mean BMI'] )   # row index value, column index value (name)  (returns Series)
display( data.loc['Brazil', ['Mean BMI']])   # row index value, column index value (name) (returns DataFrame)
# Out:
# Country/Region/World
# Brazil    17.527834
# Brazil    17.571680
# Brazil    17.615716
# Brazil    17.660124
# Brazil    17.705389
#             ...
# Brazil    19.828358
# Brazil    19.922935
# Brazil    20.020112
# Brazil    20.118750
# Brazil    20.217418
# Name: Mean BMI, Length: 84, dtype: float64
#                        Mean BMI
# Country/Region/World
# Brazil                17.527834
# Brazil                17.571680
# Brazil                17.615716
# Brazil                17.660124
# Brazil                17.705389
# ...                         ...
# Brazil                19.828358
# Brazil                19.922935
# Brazil                20.020112
# Brazil                20.118750
# Brazil                20.217418
#
# [84 rows x 1 columns]

# %%
display( data.loc[ ['Argentina', 'Brazil'], ['Year','Mean BMI'] ] )   # row index values, column index values (name)
# Out:
#                       Year   Mean BMI
# Country/Region/World
# Argentina             1975  18.399025
# Argentina             1976  18.445722
# Argentina             1977  18.493045
# Argentina             1978  18.540308
# Argentina             1979  18.587889
# ...                    ...        ...
# Brazil                2012  19.828358
# Brazil                2013  19.922935
# Brazil                2014  20.020112
# Brazil                2015  20.118750
# Brazil                2016  20.217418
#
# [168 rows x 2 columns]

# %%
# Boolean selection
# Notar que assim posso selecionar linhas usando cualquer coluna, mesmo não sendo index
mymask = data['Year']>=2000
display(mymask)
display( data.loc[ mymask , ['Year','Mean BMI'] ] )
# Out:
# Country/Region/World
# Afghanistan    False
# Afghanistan    False
# Afghanistan    False
# Afghanistan    False
# Afghanistan    False
#                ...
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Name: Year, Length: 16800, dtype: bool
#                       Year   Mean BMI
# Country/Region/World
# Afghanistan           2000  16.045675
# Afghanistan           2001  16.092205
# Afghanistan           2002  16.139320
# Afghanistan           2003  16.186949
# Afghanistan           2004  16.234814
# ...                    ...        ...
# Zimbabwe              2012  18.397532
# Zimbabwe              2013  18.403608
# Zimbabwe              2014  18.412239
# Zimbabwe              2015  18.422837
# Zimbabwe              2016  18.433654
#
# [6800 rows x 2 columns]

# %% [markdown]
# ### Usando integer location: `.iloc[]`
# - Seleccionar linhas e colunas pela **posição** dos index

# %%
data.iloc[0:3, [4, 6]]
# Out:
#                       Mean BMI lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         12.512560
# Afghanistan                                         12.634216
# Afghanistan                                         12.755636
#
#                       Prevalence of BMI>2SD (obesity)
# Country/Region/World
# Afghanistan                                  0.000517
# Afghanistan                                  0.000560
# Afghanistan                                  0.000611

# %%
# Verificando que .loc escolhe index por valor e .iloc por posição
df = pd.DataFrame(np.random.randint(20, size=(3,2)),
            index = [2, 7, 12], 
            columns=['x', 'y'])
display(df)
# Out:
#      x   y
# 2    9   6
# 7   13  17
# 12  15   6

# %%
display(df.loc[2])
display(df.iloc[2])
# Out:
# x    9
# y    6
# Name: 2, dtype: int64
# x    15
# y     6
# Name: 12, dtype: int64

# %% [markdown]
# ## `Series`
# `pd.Series(data, index=index)`
# > - Básicamente, como se fosse um `DataFrame` de uma coluna só.
# > - Os jeitos de seleccionar linhas são semelhantes aos do DataFrame mas tem alguns jeitinhos próprios também.
# > - *Eu não acho muito útil mas tem que saber que existe e estar preparado para usar*

# %%
dados = np.random.randint(100, size=8)
ser = pd.Series(dados)
display(ser, type(ser))
print(ser.index)
print(ser.values)
print(type(ser.values))
# Out:
# 0    31
# 1    66
# 2    84
# 3    37
# 4     6
# 5    99
# 6    31
# 7    50
# dtype: int64
# pandas.core.series.Series
# RangeIndex(start=0, stop=8, step=1)
# [31 66 84 37  6 99 31 50]
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Pedir uma única coluna de um DataFrame devolve ela como Series

# %%
data2 = data['ISO']
display( data2 )
print( type(data2) )
display( data2.loc[['Argentina', 'Colombia']] )   # selecting with .loc
# Out:
# Country/Region/World
# Afghanistan    AFG
# Afghanistan    AFG
# Afghanistan    AFG
# Afghanistan    AFG
# Afghanistan    AFG
#               ...
# Zimbabwe       ZWE
# Zimbabwe       ZWE
# Zimbabwe       ZWE
# Zimbabwe       ZWE
# Zimbabwe       ZWE
# Name: ISO, Length: 16800, dtype: object
# <class 'pandas.core.series.Series'>
# Country/Region/World
# Argentina    ARG
# Argentina    ARG
# Argentina    ARG
# Argentina    ARG
# Argentina    ARG
#             ...
# Colombia     COL
# Colombia     COL
# Colombia     COL
# Colombia     COL
# Colombia     COL
# Name: ISO, Length: 168, dtype: object

# %%
# Para forçar pegar como dataframe, pode pedir a coluna como uma lista com um único elemento
data2 = data[ ['ISO'] ]
display( data2 )
print( type(data2) )
# Out:
#                       ISO
# Country/Region/World
# Afghanistan           AFG
# Afghanistan           AFG
# Afghanistan           AFG
# Afghanistan           AFG
# Afghanistan           AFG
# ...                   ...
# Zimbabwe              ZWE
# Zimbabwe              ZWE
# Zimbabwe              ZWE
# Zimbabwe              ZWE
# Zimbabwe              ZWE
#
# [16800 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Views vs. Copies!
# > O comportamento de *views* vs. *copies* em Pandas é obscuro e pouco confiável. Os conselhos para evitar erros inesperados são:
# > - É difícil garantir que algo vai ficar um *view*.
# > - Se você sabe que quer uma copia, sempre explicite com `.copy()`
# > - Atenção ao uso de `inplace = True` (por default muitas funções/métodos que operam sobre um DataFrame devolvem uma copia em vez de modificar o original)
# > - Se você quer modificar o conteúdo de alguma/s celda/s do dataframe, indique a posição **dentro de um único `[]`** para evitar o chamado "chained indexing".
# - https://www.practicaldatascience.org/html/views_and_copies_in_pandas.html
# - https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-view-versus-copy

# %%
data = pd.read_csv('bmi_world.csv', index_col='Country/Region/World')
data
# Out:
#                       ISO    Sex  Year   Mean BMI  \
# Country/Region/World
# Afghanistan           AFG    Men  1975  15.045565
# Afghanistan           AFG    Men  1976  15.084892
# Afghanistan           AFG    Men  1977  15.123787
# Afghanistan           AFG    Men  1978  15.162724
# Afghanistan           AFG    Men  1979  15.202452
# ...                   ...    ...   ...        ...
# Zimbabwe              ZWE  Women  2012  18.397532
# Zimbabwe              ZWE  Women  2013  18.403608
# Zimbabwe              ZWE  Women  2014  18.412239
# Zimbabwe              ZWE  Women  2015  18.422837
# Zimbabwe              ZWE  Women  2016  18.433654
#
#                       Mean BMI lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         12.512560
# Afghanistan                                         12.634216
# Afghanistan                                         12.755636
# Afghanistan                                         12.874059
# Afghanistan                                         12.981646
# ...                                                       ...
# Zimbabwe                                            17.523243
# Zimbabwe                                            17.527503
# Zimbabwe                                            17.528672
# Zimbabwe                                            17.526655
# Zimbabwe                                            17.512160
#
#                       Mean BMI upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         17.552854
# Afghanistan                                         17.534976
# Afghanistan                                         17.502263
# Afghanistan                                         17.470846
# Afghanistan                                         17.462874
# ...                                                       ...
# Zimbabwe                                            19.282932
# Zimbabwe                                            19.300005
# Zimbabwe                                            19.308319
# Zimbabwe                                            19.319873
# Zimbabwe                                            19.359993
#
#                       Prevalence of BMI>2SD (obesity)  \
# Country/Region/World
# Afghanistan                                  0.000517
# Afghanistan                                  0.000560
# Afghanistan                                  0.000611
# Afghanistan                                  0.000671
# Afghanistan                                  0.000740
# ...                                               ...
# Zimbabwe                                     0.047494
# Zimbabwe                                     0.051572
# Zimbabwe                                     0.055903
# Zimbabwe                                     0.060503
# Zimbabwe                                     0.065392
#
#                       Prevalence of BMI>2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.000003
# Afghanistan                                                    0.000004
# Afghanistan                                                    0.000006
# Afghanistan                                                    0.000008
# Afghanistan                                                    0.000010
# ...                                                                 ...
# Zimbabwe                                                       0.016632
# Zimbabwe                                                       0.017634
# Zimbabwe                                                       0.018745
# Zimbabwe                                                       0.019798
# Zimbabwe                                                       0.020502
#
#                       Prevalence of BMI>2SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.003211
# Afghanistan                                                    0.003240
# Afghanistan                                                    0.003540
# Afghanistan                                                    0.003754
# Afghanistan                                                    0.004005
# ...                                                                 ...
# Zimbabwe                                                       0.100410
# Zimbabwe                                                       0.109708
# Zimbabwe                                                       0.119722
# Zimbabwe                                                       0.130000
# Zimbabwe                                                       0.142068
#
#                       Prevalence of BMI>1SD (overweight)  ...  \
# Country/Region/World                                      ...
# Afghanistan                                     0.003053  ...
# Afghanistan                                     0.003319  ...
# Afghanistan                                     0.003619  ...
# Afghanistan                                     0.003956  ...
# Afghanistan                                     0.004334  ...
# ...                                                  ...  ...
# Zimbabwe                                        0.185233  ...
# Zimbabwe                                        0.194297  ...
# Zimbabwe                                        0.203623  ...
# Zimbabwe                                        0.213235  ...
# Zimbabwe                                        0.223151  ...
#
#                       Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.452694
# Afghanistan                                                    0.451834
# Afghanistan                                                    0.451514
# Afghanistan                                                    0.450514
# Afghanistan                                                    0.448919
# ...                                                                 ...
# Zimbabwe                                                       0.710953
# Zimbabwe                                                       0.710982
# Zimbabwe                                                       0.711459
# Zimbabwe                                                       0.711302
# Zimbabwe                                                       0.712524
#
#                       Prevalence of minus2SD<BMI<minus1SD  \
# Country/Region/World
# Afghanistan                                      0.382075
# Afghanistan                                      0.380632
# Afghanistan                                      0.379172
# Afghanistan                                      0.377684
# Afghanistan                                      0.376138
# ...                                                   ...
# Zimbabwe                                         0.147573
# Zimbabwe                                         0.143132
# Zimbabwe                                         0.138744
# Zimbabwe                                         0.134411
# Zimbabwe                                         0.130116
#
#                       Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.240744
# Afghanistan                                                    0.243738
# Afghanistan                                                    0.245647
# Afghanistan                                                    0.247541
# Afghanistan                                                    0.249439
# ...                                                                 ...
# Zimbabwe                                                       0.098637
# Zimbabwe                                                       0.092936
# Zimbabwe                                                       0.087909
# Zimbabwe                                                       0.081897
# Zimbabwe                                                       0.076494
#
#                       Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.548096
# Afghanistan                                                    0.542044
# Afghanistan                                                    0.535515
# Afghanistan                                                    0.528804
# Afghanistan                                                    0.523514
# ...                                                                 ...
# Zimbabwe                                                       0.201325
# Zimbabwe                                                       0.198523
# Zimbabwe                                                       0.195503
# Zimbabwe                                                       0.193685
# Zimbabwe                                                       0.192211
#
#                       Prevalence of BMI<minus1SD (underweight)  \
# Country/Region/World
# Afghanistan                                           0.701622
# Afghanistan                                           0.698587
# Afghanistan                                           0.695497
# Afghanistan                                           0.692353
# Afghanistan                                           0.689128
# ...                                                        ...
# Zimbabwe                                              0.172943
# Zimbabwe                                              0.166850
# Zimbabwe                                              0.160923
# Zimbabwe                                              0.155169
# Zimbabwe                                              0.149565
#
#                       Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.543184
# Afghanistan                                                    0.544105
# Afghanistan                                                    0.544872
# Afghanistan                                                    0.544228
# Afghanistan                                                    0.544682
# ...                                                                 ...
# Zimbabwe                                                       0.120780
# Zimbabwe                                                       0.113879
# Zimbabwe                                                       0.106772
# Zimbabwe                                                       0.099421
# Zimbabwe                                                       0.092851
#
#                       Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.845123
# Afghanistan                                                    0.837919
# Afghanistan                                                    0.831829
# Afghanistan                                                    0.826128
# Afghanistan                                                    0.819239
# ...                                                                 ...
# Zimbabwe                                                       0.231131
# Zimbabwe                                                       0.227143
# Zimbabwe                                                       0.221977
# Zimbabwe                                                       0.218065
# Zimbabwe                                                       0.216192
#
#                       Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# Country/Region/World
# Afghanistan                                                    0.319547
# Afghanistan                                                    0.317956
# Afghanistan                                                    0.316325
# Afghanistan                                                    0.314669
# Afghanistan                                                    0.312990
# ...                                                                 ...
# Zimbabwe                                                       0.025371
# Zimbabwe                                                       0.023718
# Zimbabwe                                                       0.022179
# Zimbabwe                                                       0.020758
# Zimbabwe                                                       0.019449
#
#                       Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.134384
# Afghanistan                                                    0.137219
# Afghanistan                                                    0.140390
# Afghanistan                                                    0.141116
# Afghanistan                                                    0.144076
# ...                                                                 ...
# Zimbabwe                                                       0.008529
# Zimbabwe                                                       0.007467
# Zimbabwe                                                       0.006387
# Zimbabwe                                                       0.005504
# Zimbabwe                                                       0.004590
#
#                       Prevalence of BMI<minus2SD upper 95% uncertainty interval
# Country/Region/World
# Afghanistan                                                    0.498794
# Afghanistan                                                    0.492346
# Afghanistan                                                    0.486938
# Afghanistan                                                    0.482551
# Afghanistan                                                    0.477112
# ...                                                                 ...
# Zimbabwe                                                       0.053849
# Zimbabwe                                                       0.051700
# Zimbabwe                                                       0.049882
# Zimbabwe                                                       0.048322
# Zimbabwe                                                       0.047662
#
# [16800 rows x 27 columns]

# %%
# Quero somar 1 ao BMI médio de Afghanistan
# ... teria dois jeitos de seleccionar esa parte da tabela:
display(data.loc['Afghanistan','Mean BMI'])  # recomendado
display(data.lo
c['Afghanistan']['Mean BMI'])
# Out:
# Country/Region/World
# Afghanistan    15.045565
# Afghanistan    15.084892
# Afghanistan    15.123787
# Afghanistan    15.162724
# Afghanistan    15.202452
#                  ...
# Afghanistan    17.978578
# Afghanistan    18.044973
# Afghanistan    18.113052
# Afghanistan    18.182339
# Afghanistan    18.251797
# Name: Mean BMI, Length: 84, dtype: float64
# Country/Region/World
# Afghanistan    15.045565
# Afghanistan    15.084892
# Afghanistan    15.123787
# Afghanistan    15.162724
# Afghanistan    15.202452
#                  ...
# Afghanistan    17.978578
# Afghanistan    18.044973
# Afghanistan    18.113052
# Afghanistan    18.182339
# Afghanistan    18.251797
# Name: Mean BMI, Length: 84, dtype: float64

# %%
# Para mudar os valores esta funciona certinho:
data.loc['Afghanistan','Mean BMI'] +=1
display( data.head() )  # (head selecciona as primeiras 5 linhas do DataFrame)
# Out:
#                       ISO  Sex  Year   Mean BMI  \
# Country/Region/World
# Afghanistan           AFG  Men  1975  16.045565
# Afghanistan           AFG  Men  1976  16.084892
# Afghanistan           AFG  Men  1977  16.123787
# Afghanistan           AFG  Men  1978  16.162724
# Afghanistan           AFG  Men  1979  16.202452
#
#                       Mean BMI lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         12.512560
# Afghanistan                                         12.634216
# Afghanistan                                         12.755636
# Afghanistan                                         12.874059
# Afghanistan                                         12.981646
#
#                       Mean BMI upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         17.552854
# Afghanistan                                         17.534976
# Afghanistan                                         17.502263
# Afghanistan                                         17.470846
# Afghanistan                                         17.462874
#
#                       Prevalence of BMI>2SD (obesity)  \
# Country/Region/World
# Afghanistan                                  0.000517
# Afghanistan                                  0.000560
# Afghanistan                                  0.000611
# Afghanistan                                  0.000671
# Afghanistan                                  0.000740
#
#                       Prevalence of BMI>2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.000003
# Afghanistan                                                    0.000004
# Afghanistan                                                    0.000006
# Afghanistan                                                    0.000008
# Afghanistan                                                    0.000010
#
#                       Prevalence of BMI>2SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.003211
# Afghanistan                                                    0.003240
# Afghanistan                                                    0.003540
# Afghanistan                                                    0.003754
# Afghanistan                                                    0.004005
#
#                       Prevalence of BMI>1SD (overweight)  ...  \
# Country/Region/World                                      ...
# Afghanistan                                     0.003053  ...
# Afghanistan                                     0.003319  ...
# Afghanistan                                     0.003619  ...
# Afghanistan                                     0.003956  ...
# Afghanistan                                     0.004334  ...
#
#                       Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.452694
# Afghanistan                                                    0.451834
# Afghanistan                                                    0.451514
# Afghanistan                                                    0.450514
# Afghanistan                                                    0.448919
#
#                       Prevalence of minus2SD<BMI<minus1SD  \
# Country/Region/World
# Afghanistan                                      0.382075
# Afghanistan                                      0.380632
# Afghanistan                                      0.379172
# Afghanistan                                      0.377684
# Afghanistan                                      0.376138
#
#                       Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.240744
# Afghanistan                                                    0.243738
# Afghanistan                                                    0.245647
# Afghanistan                                                    0.247541
# Afghanistan                                                    0.249439
#
#                       Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.548096
# Afghanistan                                                    0.542044
# Afghanistan                                                    0.535515
# Afghanistan                                                    0.528804
# Afghanistan                                                    0.523514
#
#                       Prevalence of BMI<minus1SD (underweight)  \
# Country/Region/World
# Afghanistan                                           0.701622
# Afghanistan                                           0.698587
# Afghanistan                                           0.695497
# Afghanistan                                           0.692353
# Afghanistan                                           0.689128
#
#                       Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.543184
# Afghanistan                                                    0.544105
# Afghanistan                                                    0.544872
# Afghanistan                                                    0.544228
# Afghanistan                                                    0.544682
#
#                       Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.845123
# Afghanistan                                                    0.837919
# Afghanistan                                                    0.831829
# Afghanistan                                                    0.826128
# Afghanistan                                                    0.819239
#
#                       Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# Country/Region/World
# Afghanistan                                                    0.319547
# Afghanistan                                                    0.317956
# Afghanistan                                                    0.316325
# Afghanistan                                                    0.314669
# Afghanistan                                                    0.312990
#
#                       Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.134384
# Afghanistan                                                    0.137219
# Afghanistan                                                    0.140390
# Afghanistan                                                    0.141116
# Afghanistan                                                    0.144076
#
#                       Prevalence of BMI<minus2SD upper 95% uncertainty interval
# Country/Region/World
# Afghanistan                                                    0.498794
# Afghanistan                                                    0.492346
# Afghanistan                                                    0.486938
# Afghanistan                                                    0.482551
# Afghanistan                                                    0.477112
#
# [5 rows x 27 columns]

# %%
# E esta falha miseravelmente:
data.loc['Afghanistan']['Mean BMI'] += 1
display( data.head() )

# se aparecer esse warning recomendo mudar o código até eliminar
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       ISO  Sex  Year   Mean BMI  \
# Country/Region/World
# Afghanistan           AFG  Men  1975  16.045565
# Afghanistan           AFG  Men  1976  16.084892
# Afghanistan           AFG  Men  1977  16.123787
# Afghanistan           AFG  Men  1978  16.162724
# Afghanistan           AFG  Men  1979  16.202452
#
#                       Mean BMI lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         12.512560
# Afghanistan                                         12.634216
# Afghanistan                                         12.755636
# Afghanistan                                         12.874059
# Afghanistan                                         12.981646
#
#                       Mean BMI upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         17.552854
# Afghanistan                                         17.534976
# Afghanistan                                         17.502263
# Afghanistan                                         17.470846
# Afghanistan                                         17.462874
#
#                       Prevalence of BMI>2SD (obesity)  \
# Country/Region/World
# Afghanistan                                  0.000517
# Afghanistan                                  0.000560
# Afghanistan                                  0.000611
# Afghanistan                                  0.000671
# Afghanistan                                  0.000740
#
#                       Prevalence of BMI>2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.000003
# Afghanistan                                                    0.000004
# Afghanistan                                                    0.000006
# Afghanistan                                                    0.000008
# Afghanistan                                                    0.000010
#
#                       Prevalence of BMI>2SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.003211
# Afghanistan                                                    0.003240
# Afghanistan                                                    0.003540
# Afghanistan                                                    0.003754
# Afghanistan                                                    0.004005
#
#                       Prevalence of BMI>1SD (overweight)  ...  \
# Country/Region/World                                      ...
# Afghanistan                                     0.003053  ...
# Afghanistan                                     0.003319  ...
# Afghanistan                                     0.003619  ...
# Afghanistan                                     0.003956  ...
# Afghanistan                                     0.004334  ...
#
#                       Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.452694
# Afghanistan                                                    0.451834
# Afghanistan                                                    0.451514
# Afghanistan                                                    0.450514
# Afghanistan                                                    0.448919
#
#                       Prevalence of minus2SD<BMI<minus1SD  \
# Country/Region/World
# Afghanistan                                      0.382075
# Afghanistan                                      0.380632
# Afghanistan                                      0.379172
# Afghanistan                                      0.377684
# Afghanistan                                      0.376138
#
#                       Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.240744
# Afghanistan                                                    0.243738
# Afghanistan                                                    0.245647
# Afghanistan                                                    0.247541
# Afghanistan                                                    0.249439
#
#                       Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.548096
# Afghanistan                                                    0.542044
# Afghanistan                                                    0.535515
# Afghanistan                                                    0.528804
# Afghanistan                                                    0.523514
#
#                       Prevalence of BMI<minus1SD (underweight)  \
# Country/Region/World
# Afghanistan                                           0.701622
# Afghanistan                                           0.698587
# Afghanistan                                           0.695497
# Afghanistan                                           0.692353
# Afghanistan                                           0.689128
#
#                       Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.543184
# Afghanistan                                                    0.544105
# Afghanistan                                                    0.544872
# Afghanistan                                                    0.544228
# Afghanistan                                                    0.544682
#
#                       Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.845123
# Afghanistan                                                    0.837919
# Afghanistan                                                    0.831829
# Afghanistan                                                    0.826128
# Afghanistan                                                    0.819239
#
#                       Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# Country/Region/World
# Afghanistan                                                    0.319547
# Afghanistan                                                    0.317956
# Afghanistan                                                    0.316325
# Afghanistan                                                    0.314669
# Afghanistan                                                    0.312990
#
#                       Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.134384
# Afghanistan                                                    0.137219
# Afghanistan                                                    0.140390
# Afghanistan                                                    0.141116
# Afghanistan                                                    0.144076
#
#                       Prevalence of BMI<minus2SD upper 95% uncertainty interval
# Country/Region/World
# Afghanistan                                                    0.498794
# Afghanistan                                                    0.492346
# Afghanistan                                                    0.486938
# Afghanistan                                                    0.482551
# Afghanistan                                                    0.477112
#
# [5 rows x 27 columns]

# %%
# Quando quiser pegar uma copia de uma parte da tabela, use .copy()
data_afg = data.loc['Afghanistan'].copy()
data_afg['Mean BMI'] += 10
display( data_afg.head() )
# Out:
#                       ISO  Sex  Year   Mean BMI  \
# Country/Region/World
# Afghanistan           AFG  Men  1975  26.045565
# Afghanistan           AFG  Men  1976  26.084892
# Afghanistan           AFG  Men  1977  26.123787
# Afghanistan           AFG  Men  1978  26.162724
# Afghanistan           AFG  Men  1979  26.202452
#
#                       Mean BMI lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         12.512560
# Afghanistan                                         12.634216
# Afghanistan                                         12.755636
# Afghanistan                                         12.874059
# Afghanistan                                         12.981646
#
#                       Mean BMI upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         17.552854
# Afghanistan                                         17.534976
# Afghanistan                                         17.502263
# Afghanistan                                         17.470846
# Afghanistan                                         17.462874
#
#                       Prevalence of BMI>2SD (obesity)  \
# Country/Region/World
# Afghanistan                                  0.000517
# Afghanistan                                  0.000560
# Afghanistan                                  0.000611
# Afghanistan                                  0.000671
# Afghanistan                                  0.000740
#
#                       Prevalence of BMI>2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.000003
# Afghanistan                                                    0.000004
# Afghanistan                                                    0.000006
# Afghanistan                                                    0.000008
# Afghanistan                                                    0.000010
#
#                       Prevalence of BMI>2SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.003211
# Afghanistan                                                    0.003240
# Afghanistan                                                    0.003540
# Afghanistan                                                    0.003754
# Afghanistan                                                    0.004005
#
#                       Prevalence of BMI>1SD (overweight)  ...  \
# Country/Region/World                                      ...
# Afghanistan                                     0.003053  ...
# Afghanistan                                     0.003319  ...
# Afghanistan                                     0.003619  ...
# Afghanistan                                     0.003956  ...
# Afghanistan                                     0.004334  ...
#
#                       Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.452694
# Afghanistan                                                    0.451834
# Afghanistan                                                    0.451514
# Afghanistan                                                    0.450514
# Afghanistan                                                    0.448919
#
#                       Prevalence of minus2SD<BMI<minus1SD  \
# Country/Region/World
# Afghanistan                                      0.382075
# Afghanistan                                      0.380632
# Afghanistan                                      0.379172
# Afghanistan                                      0.377684
# Afghanistan                                      0.376138
#
#                       Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.240744
# Afghanistan                                                    0.243738
# Afghanistan                                                    0.245647
# Afghanistan                                                    0.247541
# Afghanistan                                                    0.249439
#
#                       Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.548096
# Afghanistan                                                    0.542044
# Afghanistan                                                    0.535515
# Afghanistan                                                    0.528804
# Afghanistan                                                    0.523514
#
#                       Prevalence of BMI<minus1SD (underweight)  \
# Country/Region/World
# Afghanistan                                           0.701622
# Afghanistan                                           0.698587
# Afghanistan                                           0.695497
# Afghanistan                                           0.692353
# Afghanistan                                           0.689128
#
#                       Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.543184
# Afghanistan                                                    0.544105
# Afghanistan                                                    0.544872
# Afghanistan                                                    0.544228
# Afghanistan                                                    0.544682
#
#                       Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.845123
# Afghanistan                                                    0.837919
# Afghanistan                                                    0.831829
# Afghanistan                                                    0.826128
# Afghanistan                                                    0.819239
#
#                       Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# Country/Region/World
# Afghanistan                                                    0.319547
# Afghanistan                                                    0.317956
# Afghanistan                                                    0.316325
# Afghanistan                                                    0.314669
# Afghanistan                                                    0.312990
#
#                       Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.134384
# Afghanistan                                                    0.137219
# Afghanistan                                                    0.140390
# Afghanistan                                                    0.141116
# Afghanistan                                                    0.144076
#
#                       Prevalence of BMI<minus2SD upper 95% uncertainty interval
# Country/Region/World
# Afghanistan                                                    0.498794
# Afghanistan                                                    0.492346
# Afghanistan                                                    0.486938
# Afghanistan                                                    0.482551
# Afghanistan                                                    0.477112
#
# [5 rows x 27 columns]

# %%
# Algumas funções que modifican DataFrames recebem o parámetro 'inplace':
# ... inplace=False -> devolver uma copia modificada do DataFrame e deixar o original intacto
data.reset_index()
display( data )

data2 = data.reset_index()
display( data2 )
# Out:
#                       ISO    Sex  Year   Mean BMI  \
# Country/Region/World
# Afghanistan           AFG    Men  1975  16.045565
# Afghanistan           AFG    Men  1976  16.084892
# Afghanistan           AFG    Men  1977  16.123787
# Afghanistan           AFG    Men  1978  16.162724
# Afghanistan           AFG    Men  1979  16.202452
# ...                   ...    ...   ...        ...
# Zimbabwe              ZWE  Women  2012  18.397532
# Zimbabwe              ZWE  Women  2013  18.403608
# Zimbabwe              ZWE  Women  2014  18.412239
# Zimbabwe              ZWE  Women  2015  18.422837
# Zimbabwe              ZWE  Women  2016  18.433654
#
#                       Mean BMI lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         12.512560
# Afghanistan                                         12.634216
# Afghanistan                                         12.755636
# Afghanistan                                         12.874059
# Afghanistan                                         12.981646
# ...                                                       ...
# Zimbabwe                                            17.523243
# Zimbabwe                                            17.527503
# Zimbabwe                                            17.528672
# Zimbabwe                                            17.526655
# Zimbabwe                                            17.512160
#
#                       Mean BMI upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                         17.552854
# Afghanistan                                         17.534976
# Afghanistan                                         17.502263
# Afghanistan                                         17.470846
# Afghanistan                                         17.462874
# ...                                                       ...
# Zimbabwe                                            19.282932
# Zimbabwe                                            19.300005
# Zimbabwe                                            19.308319
# Zimbabwe                                            19.319873
# Zimbabwe                                            19.359993
#
#                       Prevalence of BMI>2SD (obesity)  \
# Country/Region/World
# Afghanistan                                  0.000517
# Afghanistan                                  0.000560
# Afghanistan                                  0.000611
# Afghanistan                                  0.000671
# Afghanistan                                  0.000740
# ...                                               ...
# Zimbabwe                                     0.047494
# Zimbabwe                                     0.051572
# Zimbabwe                                     0.055903
# Zimbabwe                                     0.060503
# Zimbabwe                                     0.065392
#
#                       Prevalence of BMI>2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.000003
# Afghanistan                                                    0.000004
# Afghanistan                                                    0.000006
# Afghanistan                                                    0.000008
# Afghanistan                                                    0.000010
# ...                                                                 ...
# Zimbabwe                                                       0.016632
# Zimbabwe                                                       0.017634
# Zimbabwe                                                       0.018745
# Zimbabwe                                                       0.019798
# Zimbabwe                                                       0.020502
#
#                       Prevalence of BMI>2SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.003211
# Afghanistan                                                    0.003240
# Afghanistan                                                    0.003540
# Afghanistan                                                    0.003754
# Afghanistan                                                    0.004005
# ...                                                                 ...
# Zimbabwe                                                       0.100410
# Zimbabwe                                                       0.109708
# Zimbabwe                                                       0.119722
# Zimbabwe                                                       0.130000
# Zimbabwe                                                       0.142068
#
#                       Prevalence of BMI>1SD (overweight)  ...  \
# Country/Region/World                                      ...
# Afghanistan                                     0.003053  ...
# Afghanistan                                     0.003319  ...
# Afghanistan                                     0.003619  ...
# Afghanistan                                     0.003956  ...
# Afghanistan                                     0.004334  ...
# ...                                                  ...  ...
# Zimbabwe                                        0.185233  ...
# Zimbabwe                                        0.194297  ...
# Zimbabwe                                        0.203623  ...
# Zimbabwe                                        0.213235  ...
# Zimbabwe                                        0.223151  ...
#
#                       Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.452694
# Afghanistan                                                    0.451834
# Afghanistan                                                    0.451514
# Afghanistan                                                    0.450514
# Afghanistan                                                    0.448919
# ...                                                                 ...
# Zimbabwe                                                       0.710953
# Zimbabwe                                                       0.710982
# Zimbabwe                                                       0.711459
# Zimbabwe                                                       0.711302
# Zimbabwe                                                       0.712524
#
#                       Prevalence of minus2SD<BMI<minus1SD  \
# Country/Region/World
# Afghanistan                                      0.382075
# Afghanistan                                      0.380632
# Afghanistan                                      0.379172
# Afghanistan                                      0.377684
# Afghanistan                                      0.376138
# ...                                                   ...
# Zimbabwe                                         0.147573
# Zimbabwe                                         0.143132
# Zimbabwe                                         0.138744
# Zimbabwe                                         0.134411
# Zimbabwe                                         0.130116
#
#                       Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.240744
# Afghanistan                                                    0.243738
# Afghanistan                                                    0.245647
# Afghanistan                                                    0.247541
# Afghanistan                                                    0.249439
# ...                                                                 ...
# Zimbabwe                                                       0.098637
# Zimbabwe                                                       0.092936
# Zimbabwe                                                       0.087909
# Zimbabwe                                                       0.081897
# Zimbabwe                                                       0.076494
#
#                       Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.548096
# Afghanistan                                                    0.542044
# Afghanistan                                                    0.535515
# Afghanistan                                                    0.528804
# Afghanistan                                                    0.523514
# ...                                                                 ...
# Zimbabwe                                                       0.201325
# Zimbabwe                                                       0.198523
# Zimbabwe                                                       0.195503
# Zimbabwe                                                       0.193685
# Zimbabwe                                                       0.192211
#
#                       Prevalence of BMI<minus1SD (underweight)  \
# Country/Region/World
# Afghanistan                                           0.701622
# Afghanistan                                           0.698587
# Afghanistan                                           0.695497
# Afghanistan                                           0.692353
# Afghanistan                                           0.689128
# ...                                                        ...
# Zimbabwe                                              0.172943
# Zimbabwe                                              0.166850
# Zimbabwe                                              0.160923
# Zimbabwe                                              0.155169
# Zimbabwe                                              0.149565
#
#                       Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.543184
# Afghanistan                                                    0.544105
# Afghanistan                                                    0.544872
# Afghanistan                                                    0.544228
# Afghanistan                                                    0.544682
# ...                                                                 ...
# Zimbabwe                                                       0.120780
# Zimbabwe                                                       0.113879
# Zimbabwe                                                       0.106772
# Zimbabwe                                                       0.099421
# Zimbabwe                                                       0.092851
#
#                       Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.845123
# Afghanistan                                                    0.837919
# Afghanistan                                                    0.831829
# Afghanistan                                                    0.826128
# Afghanistan                                                    0.819239
# ...                                                                 ...
# Zimbabwe                                                       0.231131
# Zimbabwe                                                       0.227143
# Zimbabwe                                                       0.221977
# Zimbabwe                                                       0.218065
# Zimbabwe                                                       0.216192
#
#                       Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# Country/Region/World
# Afghanistan                                                    0.319547
# Afghanistan                                                    0.317956
# Afghanistan                                                    0.316325
# Afghanistan                                                    0.314669
# Afghanistan                                                    0.312990
# ...                                                                 ...
# Zimbabwe                                                       0.025371
# Zimbabwe                                                       0.023718
# Zimbabwe                                                       0.022179
# Zimbabwe                                                       0.020758
# Zimbabwe                                                       0.019449
#
#                       Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# Country/Region/World
# Afghanistan                                                    0.134384
# Afghanistan                                                    0.137219
# Afghanistan                                                    0.140390
# Afghanistan                                                    0.141116
# Afghanistan                                                    0.144076
# ...                                                                 ...
# Zimbabwe                                                       0.008529
# Zimbabwe                                                       0.007467
# Zimbabwe                                                       0.006387
# Zimbabwe                                                       0.005504
# Zimbabwe                                                       0.004590
#
#                       Prevalence of BMI<minus2SD upper 95% uncertainty interval
# Country/Region/World
# Afghanistan                                                    0.498794
# Afghanistan                                                    0.492346
# Afghanistan                                                    0.486938
# Afghanistan                                                    0.482551
# Afghanistan                                                    0.477112
# ...                                                                 ...
# Zimbabwe                                                       0.053849
# Zimbabwe                                                       0.051700
# Zimbabwe                                                       0.049882
# Zimbabwe                                                       0.048322
# Zimbabwe                                                       0.047662
#
# [16800 rows x 27 columns]
#       Country/Region/World  ISO    Sex  Year   Mean BMI  \
# 0              Afghanistan  AFG    Men  1975  16.045565
# 1              Afghanistan  AFG    Men  1976  16.084892
# 2              Afghanistan  AFG    Men  1977  16.123787
# 3              Afghanistan  AFG    Men  1978  16.162724
# 4              Afghanistan  AFG    Men  1979  16.202452
# ...                    ...  ...    ...   ...        ...
# 16795             Zimbabwe  ZWE  Women  2012  18.397532
# 16796             Zimbabwe  ZWE  Women  2013  18.403608
# 16797             Zimbabwe  ZWE  Women  2014  18.412239
# 16798             Zimbabwe  ZWE  Women  2015  18.422837
# 16799             Zimbabwe  ZWE  Women  2016  18.433654
#
#        Mean BMI lower 95% uncertainty interval  \
# 0                                    12.512560
# 1                                    12.634216
# 2                                    12.755636
# 3                                    12.874059
# 4                                    12.981646
# ...                                        ...
# 16795                                17.523243
# 16796                                17.527503
# 16797                                17.528672
# 16798                                17.526655
# 16799                                17.512160
#
#        Mean BMI upper 95% uncertainty interval  \
# 0                                    17.552854
# 1                                    17.534976
# 2                                    17.502263
# 3                                    17.470846
# 4                                    17.462874
# ...                                        ...
# 16795                                19.282932
# 16796                                19.300005
# 16797                                19.308319
# 16798                                19.319873
# 16799                                19.359993
#
#        Prevalence of BMI>2SD (obesity)  \
# 0                             0.000517
# 1                             0.000560
# 2                             0.000611
# 3                             0.000671
# 4                             0.000740
# ...                                ...
# 16795                         0.047494
# 16796                         0.051572
# 16797                         0.055903
# 16798                         0.060503
# 16799                         0.065392
#
#        Prevalence of BMI>2SD lower 95% uncertainty interval  \
# 0                                               0.000003
# 1                                               0.000004
# 2                                               0.000006
# 3                                               0.000008
# 4                                               0.000010
# ...                                                  ...
# 16795                                           0.016632
# 16796                                           0.017634
# 16797                                           0.018745
# 16798                                           0.019798
# 16799                                           0.020502
#
#        Prevalence of BMI>2SD upper 95% uncertainty interval  ...  \
# 0                                               0.003211     ...
# 1                                               0.003240     ...
# 2                                               0.003540     ...
# 3                                               0.003754     ...
# 4                                               0.004005     ...
# ...                                                  ...     ...
# 16795                                           0.100410     ...
# 16796                                           0.109708     ...
# 16797                                           0.119722     ...
# 16798                                           0.130000     ...
# 16799                                           0.142068     ...
#
#        Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# 0                                               0.452694
# 1                                               0.451834
# 2                                               0.451514
# 3                                               0.450514
# 4                                               0.448919
# ...                                                  ...
# 16795                                           0.710953
# 16796                                           0.710982
# 16797                                           0.711459
# 16798                                           0.711302
# 16799                                           0.712524
#
#        Prevalence of minus2SD<BMI<minus1SD  \
# 0                                 0.382075
# 1                                 0.380632
# 2                                 0.379172
# 3                                 0.377684
# 4                                 0.376138
# ...                                    ...
# 16795                             0.147573
# 16796                             0.143132
# 16797                             0.138744
# 16798                             0.134411
# 16799                             0.130116
#
#        Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# 0                                               0.240744
# 1                                               0.243738
# 2                                               0.245647
# 3                                               0.247541
# 4                                               0.249439
# ...                                                  ...
# 16795                                           0.098637
# 16796                                           0.092936
# 16797                                           0.087909
# 16798                                           0.081897
# 16799                                           0.076494
#
#        Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# 0                                               0.548096
# 1                                               0.542044
# 2                                               0.535515
# 3                                               0.528804
# 4                                               0.523514
# ...                                                  ...
# 16795                                           0.201325
# 16796                                           0.198523
# 16797                                           0.195503
# 16798                                           0.193685
# 16799                                           0.192211
#
#        Prevalence of BMI<minus1SD (underweight)  \
# 0                                      0.701622
# 1                                      0.698587
# 2                                      0.695497
# 3                                      0.692353
# 4                                      0.689128
# ...                                         ...
# 16795                                  0.172943
# 16796                                  0.166850
# 16797                                  0.160923
# 16798                                  0.155169
# 16799                                  0.149565
#
#        Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# 0                                               0.543184
# 1                                               0.544105
# 2                                               0.544872
# 3                                               0.544228
# 4                                               0.544682
# ...                                                  ...
# 16795                                           0.120780
# 16796                                           0.113879
# 16797                                           0.106772
# 16798                                           0.099421
# 16799                                           0.092851
#
#        Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# 0                                               0.845123
# 1                                               0.837919
# 2                                               0.831829
# 3                                               0.826128
# 4                                               0.819239
# ...                                                  ...
# 16795                                           0.231131
# 16796                                           0.227143
# 16797                                           0.221977
# 16798                                           0.218065
# 16799                                           0.216192
#
#        Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# 0                                               0.319547
# 1                                               0.317956
# 2                                               0.316325
# 3                                               0.314669
# 4                                               0.312990
# ...                                                  ...
# 16795                                           0.025371
# 16796                                           0.023718
# 16797                                           0.022179
# 16798                                           0.020758
# 16799                                           0.019449
#
#        Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# 0                                               0.134384
# 1                                               0.137219
# 2                                               0.140390
# 3                                               0.141116
# 4                                               0.144076
# ...                                                  ...
# 16795                                           0.008529
# 16796                                           0.007467
# 16797                                           0.006387
# 16798                                           0.005504
# 16799                                           0.004590
#
#        Prevalence of BMI<minus2SD upper 95% uncertainty interval
# 0                                               0.498794
# 1                                               0.492346
# 2                                               0.486938
# 3                                               0.482551
# 4                                               0.477112
# ...                                                  ...
# 16795                                           0.053849
# 16796                                           0.051700
# 16797                                           0.049882
# 16798                                           0.048322
# 16799                                           0.047662
#
# [16800 rows x 28 columns]

# %%
# ... inplace=True -> modificar diretamente o DataFrame
data.reset_index(inplace=True)   # equivalente a data = data.reset_index()
display( data )
# Out:
#       Country/Region/World  ISO    Sex  Year   Mean BMI  \
# 0              Afghanistan  AFG    Men  1975  16.045565
# 1              Afghanistan  AFG    Men  1976  16.084892
# 2              Afghanistan  AFG    Men  1977  16.123787
# 3              Afghanistan  AFG    Men  1978  16.162724
# 4              Afghanistan  AFG    Men  1979  16.202452
# ...                    ...  ...    ...   ...        ...
# 16795             Zimbabwe  ZWE  Women  2012  18.397532
# 16796             Zimbabwe  ZWE  Women  2013  18.403608
# 16797             Zimbabwe  ZWE  Women  2014  18.412239
# 16798             Zimbabwe  ZWE  Women  2015  18.422837
# 16799             Zimbabwe  ZWE  Women  2016  18.433654
#
#        Mean BMI lower 95% uncertainty interval  \
# 0                                    12.512560
# 1                                    12.634216
# 2                                    12.755636
# 3                                    12.874059
# 4                                    12.981646
# ...                                        ...
# 16795                                17.523243
# 16796                                17.527503
# 16797                                17.528672
# 16798                                17.526655
# 16799                                17.512160
#
#        Mean BMI upper 95% uncertainty interval  \
# 0                                    17.552854
# 1                                    17.534976
# 2                                    17.502263
# 3                                    17.470846
# 4                                    17.462874
# ...                                        ...
# 16795                                19.282932
# 16796                                19.300005
# 16797                                19.308319
# 16798                                19.319873
# 16799                                19.359993
#
#        Prevalence of BMI>2SD (obesity)  \
# 0                             0.000517
# 1                             0.000560
# 2                             0.000611
# 3                             0.000671
# 4                             0.000740
# ...                                ...
# 16795                         0.047494
# 16796                         0.051572
# 16797                         0.055903
# 16798                         0.060503
# 16799                         0.065392
#
#        Prevalence of BMI>2SD lower 95% uncertainty interval  \
# 0                                               0.000003
# 1                                               0.000004
# 2                                               0.000006
# 3                                               0.000008
# 4                                               0.000010
# ...                                                  ...
# 16795                                           0.016632
# 16796                                           0.017634
# 16797                                           0.018745
# 16798                                           0.019798
# 16799                                           0.020502
#
#        Prevalence of BMI>2SD upper 95% uncertainty interval  ...  \
# 0                                               0.003211     ...
# 1                                               0.003240     ...
# 2                                               0.003540     ...
# 3                                               0.003754     ...
# 4                                               0.004005     ...
# ...                                                  ...     ...
# 16795                                           0.100410     ...
# 16796                                           0.109708     ...
# 16797                                           0.119722     ...
# 16798                                           0.130000     ...
# 16799                                           0.142068     ...
#
#        Prevalence of minus1SD<BMI<1SD upper 95% uncertainty interval  \
# 0                                               0.452694
# 1                                               0.451834
# 2                                               0.451514
# 3                                               0.450514
# 4                                               0.448919
# ...                                                  ...
# 16795                                           0.710953
# 16796                                           0.710982
# 16797                                           0.711459
# 16798                                           0.711302
# 16799                                           0.712524
#
#        Prevalence of minus2SD<BMI<minus1SD  \
# 0                                 0.382075
# 1                                 0.380632
# 2                                 0.379172
# 3                                 0.377684
# 4                                 0.376138
# ...                                    ...
# 16795                             0.147573
# 16796                             0.143132
# 16797                             0.138744
# 16798                             0.134411
# 16799                             0.130116
#
#        Prevalence of minus2SD<BMI<minus1SD lower 95% uncertainty interval  \
# 0                                               0.240744
# 1                                               0.243738
# 2                                               0.245647
# 3                                               0.247541
# 4                                               0.249439
# ...                                                  ...
# 16795                                           0.098637
# 16796                                           0.092936
# 16797                                           0.087909
# 16798                                           0.081897
# 16799                                           0.076494
#
#        Prevalence of minus2SD<BMI<minus1SD upper 95% uncertainty interval  \
# 0                                               0.548096
# 1                                               0.542044
# 2                                               0.535515
# 3                                               0.528804
# 4                                               0.523514
# ...                                                  ...
# 16795                                           0.201325
# 16796                                           0.198523
# 16797                                           0.195503
# 16798                                           0.193685
# 16799                                           0.192211
#
#        Prevalence of BMI<minus1SD (underweight)  \
# 0                                      0.701622
# 1                                      0.698587
# 2                                      0.695497
# 3                                      0.692353
# 4                                      0.689128
# ...                                         ...
# 16795                                  0.172943
# 16796                                  0.166850
# 16797                                  0.160923
# 16798                                  0.155169
# 16799                                  0.149565
#
#        Prevalence of BMI<minus1SD lower 95% uncertainty interval  \
# 0                                               0.543184
# 1                                               0.544105
# 2                                               0.544872
# 3                                               0.544228
# 4                                               0.544682
# ...                                                  ...
# 16795                                           0.120780
# 16796                                           0.113879
# 16797                                           0.106772
# 16798                                           0.099421
# 16799                                           0.092851
#
#        Prevalence of BMI<minus1SD upper 95% uncertainty interval  \
# 0                                               0.845123
# 1                                               0.837919
# 2                                               0.831829
# 3                                               0.826128
# 4                                               0.819239
# ...                                                  ...
# 16795                                           0.231131
# 16796                                           0.227143
# 16797                                           0.221977
# 16798                                           0.218065
# 16799                                           0.216192
#
#        Prevalence of BMI<minus2SD (moderate & severe underweight)  \
# 0                                               0.319547
# 1                                               0.317956
# 2                                               0.316325
# 3                                               0.314669
# 4                                               0.312990
# ...                                                  ...
# 16795                                           0.025371
# 16796                                           0.023718
# 16797                                           0.022179
# 16798                                           0.020758
# 16799                                           0.019449
#
#        Prevalence of BMI<minus2SD lower 95% uncertainty interval  \
# 0                                               0.134384
# 1                                               0.137219
# 2                                               0.140390
# 3                                               0.141116
# 4                                               0.144076
# ...                                                  ...
# 16795                                           0.008529
# 16796                                           0.007467
# 16797                                           0.006387
# 16798                                           0.005504
# 16799                                           0.004590
#
#        Prevalence of BMI<minus2SD upper 95% uncertainty interval
# 0                                               0.498794
# 1                                               0.492346
# 2                                               0.486938
# 3                                               0.482551
# 4                                               0.477112
# ...                                                  ...
# 16795                                           0.053849
# 16796                                           0.051700
# 16797                                           0.049882
# 16798                                           0.048322
# 16799                                           0.047662
#
# [16800 rows x 28 columns]

# %% [markdown]
# ## Agreggation
# >  Significado de **Agregar**: *Fazer a reunião de muitas coisas, pessoas, elementos etc., num só corpo (local)*
# No pandas, os `DataFrames` (e `Series`) tem métodos para obter com facilidade propriedades *agregadas* dos dados.
#
# https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html

# %% [markdown]
# > O mais simples é obter aggregates de colunas (ou linhas) inteiras:
#
# <table>
# <thead><tr>
# <th>Aggregation</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>count()</code></td>
# <td>Total number of items</td>
# </tr>
# <tr>
# <td><code>first()</code>, <code>last()</code></td>
# <td>First and last item</td>
# </tr>
# <tr>
# <td><code>mean()</code>, <code>median()</code></td>
# <td>Mean and median</td>
# </tr>
# <tr>
# <td><code>min()</code>, <code>max()</code></td>
# <td>Minimum and maximum</td>
# </tr>
# <tr>
# <td><code>std()</code>, <code>var()</code></td>
# <td>Standard deviation and variance</td>
# </tr>
# <tr>
# <td><code>mad()</code></td>
# <td>Mean absolute deviation</td>
# </tr>
# <tr>
# <td><code>prod()</code></td>
# <td>Product of all items</td>
# </tr>
# <tr>
# <td><code>sum()</code></td>
# <td>Sum of all items</td>
# </tr>
# </tbody>
# </table>

# %%
filename = 'titanic_data.csv'
tit = pd.read_csv(filename, index_col=3)
display( tit )
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [891 rows x 11 columns]

# %%
display( tit.count() )

#display( tit.describe() )    # vários agreggates úteis de cada coluna
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# E se eu quiser saber a tarifa média segundo se sobreviviram ou não?
#display( tit['Survived']==1 )
display( tit.loc[ tit['Survived']==1 ] )

# Notar duas coisas:
#    Posso selecionar dados antes de fazer o aggregate para não incluir tudo.
#    Posso selecionar só alguma/s colunas do resultado do aggregate.
f0 = tit.loc[ tit['Survived']==0 , 'Fare'].mean()
f1 = tit.loc[ tit['Survived']==1 , 'Fare'].mean()

print( f'Os que sobreviveram pagaram ${f1:.1f} em media. Já os que morreram tinham, em media, pago ${f0:.1f}.' )
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# ...                                                         ...       ...
# Najib, Miss. Adele Kiamie "Jane"                            876         1
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Shelley, Mrs. William (Imanita Parrish Hall)                881         1
# Graham, Miss. Margaret Edith                                888         1
# Behr, Mr. Karl Howell                                       890         1
#
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  14.0
# ...                                                    ...     ...   ...
# Najib, Miss. Adele Kiamie "Jane"                         3  female  15.0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)            1  female  56.0
# Shelley, Mrs. William (Imanita Parrish Hall)             2  female  25.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Behr, Mr. Karl Howell                                    1    male  26.0
#
#                                                     SibSp  Parch  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       0      2
# Nasser, Mrs. Nicholas (Adele Achem)                     1      0
# ...                                                   ...    ...
# Najib, Miss. Adele Kiamie "Jane"                        0      0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)           0      1
# Shelley, Mrs. William (Imanita Parrish Hall)            0      1
# Graham, Miss. Margaret Edith                            0      0
# Behr, Mr. Karl Howell                                   0      0
#
#                                                               Ticket     Fare  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             347742  11.1333
# Nasser, Mrs. Nicholas (Adele Achem)                           237736  30.0708
# ...                                                              ...      ...
# Najib, Miss. Adele Kiamie "Jane"                                2667   7.2250
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)                  11767  83.1583
# Shelley, Mrs. William (Imanita Parrish Hall)                  230433  26.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Behr, Mr. Karl Howell                                         111369  30.0000
#
#                                                    Cabin Embarked
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    NaN        S
# Nasser, Mrs. Nicholas (Adele Achem)                  NaN        C
# ...                                                  ...      ...
# Najib, Miss. Adele Kiamie "Jane"                     NaN        C
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)        C50        C
# Shelley, Mrs. William (Imanita Parrish Hall)         NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Behr, Mr. Karl Howell                               C148        C
#
# [342 rows x 11 columns]
# Os que sobreviveram pagaram $48.4 em media. Já os que morreram tinham, em media, pago $22.1.

# %% [markdown]
# ### Aggregation with `groupby`
# > Essa história de querer calcular aggregates para diferentes condições é muito comúm. Portanto, tem métodos bonitazos para isso.
# ![groupby.png](groupby.png)

# %%
tit.groupby('Survived')['Fare'].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %%
# The GroupBy object
tit.groupby('Pclass')

# %%
# Podemos imaginar que o objeto DataFrameGroupBy tem o DataFrame original dividido em DFs menores
#display( tit.groupby('Pclass').mean() )
display( tit.groupby('Pclass')[ ['Survived'] ].mean() * 100 )
# Out:
#          Survived
# Pclass
# 1       62.962963
# 2       47.282609
# 3       24.236253

# %%
tit.groupby('Sex')[['Survived']].mean() * 100
# Out:
#          Survived
# Sex
# female  74.203822
# male    18.890815

# %%
# Agrupar por dois níveis
display( tit.groupby(['Pclass','Sex'])[['Survived']].mean() * 100 )   # las mujeres primero!
display( tit.groupby(['Pclass','Sex'])[['Survived','Age']].mean().unstack() )  # separar los niveles de multiindex de linhas para colunas
# Out:
#                 Survived
# Pclass Sex
# 1      female  96.808511
#        male    36.885246
# 2      female  92.105263
#        male    15.740741
# 3      female  50.000000
#        male    13.544669
#         Survived                  Age
# Sex       female      male     female       male
# Pclass
# 1       0.968085  0.368852  34.611765  41.281386
# 2       0.921053  0.157407  28.722973  30.740707
# 3       0.500000  0.135447  21.750000  26.507589

# %% [markdown]
# ## Agrupando por valores numéricos contínuos
# > Combinando `groupby()` con `cut()` ou `qcut()` podemos agrupar por faixas de valores numéricos.
#
# https://pbpython.com/pandas-qcut-cut.html

# %%
# Criando as categorias
age_cut = pd.cut( tit['Age'], bins=[0,2,10,18,30,40,60,100] )
display( age_cut , type(age_cut) )
# Out:
# Name
# Braund, Mr. Owen Harris                                (18.0, 30.0]
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    (30.0, 40.0]
# Heikkinen, Miss. Laina                                 (18.0, 30.0]
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           (30.0, 40.0]
# Allen, Mr. William Henry                               (30.0, 40.0]
#                                                            ...
# Montvila, Rev. Juozas                                  (18.0, 30.0]
# Graham, Miss. Margaret Edith                           (18.0, 30.0]
# Johnston, Miss. Catherine Helen "Carrie"                        NaN
# Behr, Mr. Karl Howell                                  (18.0, 30.0]
# Dooley, Mr. Patrick                                    (30.0, 40.0]
# Name: Age, Length: 891, dtype: category
# Categories (7, interval[int64]): [(0, 2] < (2, 10] < (10, 18] < (18, 30] < (30, 40] < (40, 60] < (60, 100]]
# pandas.core.series.Series

# %%
display( tit.groupby( age_cut )['PassengerId'].count() )
# Out:
# Age
# (0, 2]        24
# (2, 10]       40
# (10, 18]      75
# (18, 30]     270
# (30, 40]     155
# (40, 60]     128
# (60, 100]     22
# Name: PassengerId, dtype: int64

# %%
display( tit.groupby( age_cut )['Survived'].mean() )
display( tit.groupby( [age_cut, 'Sex'] )['Survived'].mean().unstack() )   # Agrupando por vários critérios... las mujeres y los niños??
# Out:
# Age
# (0, 2]       0.625000
# (2, 10]      0.575000
# (10, 18]     0.426667
# (18, 30]     0.355556
# (30, 40]     0.445161
# (40, 60]     0.390625
# (60, 100]    0.227273
# Name: Survived, dtype: float64
# Sex          female      male
# Age
# (0, 2]     0.600000  0.642857
# (2, 10]    0.619048  0.526316
# (10, 18]   0.729730  0.131579
# (18, 30]   0.755556  0.155556
# (30, 40]   0.836364  0.230000
# (40, 60]   0.755556  0.192771
# (60, 100]  1.000000  0.105263

# %% [markdown]
# ### More fun with `groupby()`
# > `aggregate()`, `filter()`, `transform()`, `apply()`
#
# https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html

# %% [markdown]
# ## Concatenando  DataFrames
#
# ### `pd.concat()`
# > - Junta (empilha) tabelas semelhantes em uma só. Parecido com `np.concatenate()`
# - Ver `.append()` para adicionar linhas no final.

# %%
sz1 = (5, 3)
letras = 'ABCDEFGHIJ'
df1 = pd.DataFrame(np.random.randint(20, size=sz1), 
             columns=[f'Valor_{s}' for s in letras[:sz1[1]]],     # list comprehension
             index=[f'Obs_{s}' for s in range(1,sz1[0]+1)])
display(df1)
# Out:
#        Valor_A  Valor_B  Valor_C
# Obs_1       13       15       14
# Obs_2        1       17       13
# Obs_3        7       18        4
# Obs_4        7        9       12
# Obs_5       18        4        4

# %%
# same cols, more obs
sz2 = (3, sz1[1])
df2 = pd.DataFrame(np.random.randint(-20, 0, size=sz2), 
             columns=[f'Valor_{s}' for s in letras[:sz2[1]]],
             index=[f'Obs_{s}' for s in range( 1+sz1[0],1+sz1[0]+sz2[0] )] )
display(df1,df2)

# simple concatenation
display(pd.concat([df1, df2], axis=0))
# Out:
#        Valor_A  Valor_B  Valor_C
# Obs_1       13       15       14
# Obs_2        1       17       13
# Obs_3        7       18        4
# Obs_4        7        9       12
# Obs_5       18        4        4
#        Valor_A  Valor_B  Valor_C
# Obs_6       -5      -18      -15
# Obs_7      -19       -9      -16
# Obs_8      -17      -12      -18
#        Valor_A  Valor_B  Valor_C
# Obs_1       13       15       14
# Obs_2        1       17       13
# Obs_3        7       18        4
# Obs_4        7        9       12
# Obs_5       18        4        4
# Obs_6       -5      -18      -15
# Obs_7      -19       -9      -16
# Obs_8      -17      -12      -18

# %%
# new cols, same obs
sz3 = (sz1[0], 2)
df3 = pd.DataFrame(np.random.randint(-20, 0, size=sz3), 
             columns=[f'Valor_{s}' for s in letras[sz1[1]:(sz1[1]+sz3[1])]],
             index=[f'Obs_{s}' for s in range(1,sz3[0]+1)])
display(df1, df3)

# simple concatenation on columns (axis = 1)
display(pd.concat([df1, df3], axis=1))

# What if different # of Obs?
# Out:
#        Valor_A  Valor_B  Valor_C
# Obs_1       13       15       14
# Obs_2        1       17       13
# Obs_3        7       18        4
# Obs_4        7        9       12
# Obs_5       18        4        4
#        Valor_D  Valor_E
# Obs_1      -19       -8
# Obs_2      -14      -14
# Obs_3      -20      -17
# Obs_4      -11       -6
# Obs_5      -10      -13
#        Valor_A  Valor_B  Valor_C  Valor_D  Valor_E
# Obs_1       13       15       14      -19       -8
# Obs_2        1       17       13      -14      -14
# Obs_3        7       18        4      -20      -17
# Obs_4        7        9       12      -11       -6
# Obs_5       18        4        4      -10      -13

# %%
# What if there are missing values?
sz4 = (sz1[0]-2, 2)
df4 = pd.DataFrame(np.random.randint(-20, 0, size=sz4), 
             columns=[f'Valor_{s}' for s in letras[sz1[1]:(sz1[1]+sz4[1])]],
             index=[f'Obs_{s}' for s in range(sz4[0]+1,1,-1)])
display(df1, df4)

# simple concatenation on columns (axis = 1)
display(pd.concat([df1, df4], axis=1))

# notar que os dados são alineados pelo index das líneas (não pela posição)
# Out:
#        Valor_A  Valor_B  Valor_C
# Obs_1       13       15       14
# Obs_2        1       17       13
# Obs_3        7       18        4
# Obs_4        7        9       12
# Obs_5       18        4        4
#        Valor_D  Valor_E
# Obs_4      -10      -14
# Obs_3      -20       -5
# Obs_2      -12      -11
#        Valor_A  Valor_B  Valor_C  Valor_D  Valor_E
# Obs_1       13       15       14      NaN      NaN
# Obs_2        1       17       13    -12.0    -11.0
# Obs_3        7       18        4    -20.0     -5.0
# Obs_4        7        9       12    -10.0    -14.0
# Obs_5       18        4        4      NaN      NaN

# %%
# What if there are repeated index values?
sz2 = (3, sz1[1])
df2 = pd.DataFrame(np.random.randint(-20, 0, size=sz2), 
             columns=[f'Valor_{s}' for s in letras[:sz2[1]]],
             index=[f'Obs_{s}' for s in range(sz1[0],sz1[0]+sz2[0])])
display(df1, df2)

# simple concatenation accepting repeated index
dfc = pd.concat([df1, df2])

# giving error if reapeted index
#dfc = pd.concat([df1, df2], verify_integrity=True)

# if you don't care about the indexs, just ignore them (and make a new simple one)
#dfc = pd.concat([df1, df2], ignore_index=True)

# Expand to a multi-index. In this way you can keep track of where each row came from
#dfc = pd.concat([df1, df2], keys=['roberto', 'carlos'])

display(dfc)
# Out:
#        Valor_A  Valor_B  Valor_C
# Obs_1       13       15       14
# Obs_2        1       17       13
# Obs_3        7       18        4
# Obs_4        7        9       12
# Obs_5       18        4        4
#        Valor_A  Valor_B  Valor_C
# Obs_5      -13       -2       -2
# Obs_6      -18       -7      -14
# Obs_7      -13      -18      -12
#        Valor_A  Valor_B  Valor_C
# Obs_1       13       15       14
# Obs_2        1       17       13
# Obs_3        7       18        4
# Obs_4        7        9       12
# Obs_5       18        4        4
# Obs_5      -13       -2       -2
# Obs_6      -18       -7      -14
# Obs_7      -13      -18      -12

# %% [markdown]
# ## Fusionando DataFrames
# ### `pd.merge()` e `pd.join()`
# > - Fusionar tabelas é diferente de concatenar.
# - Concatenando empilhamos tabelas semelhantes para ganhar uma tabela maior.
# - Fusionando podemos juntar informação de natureza diferente de diferentes tabelas relacionadas.
#
# https://jakevdp.github.io/PythonDataScienceHandbook/03.07-merge-and-join.html
# https://pandas.pydata.org/docs/user_guide/merging.html
# https://towardsdatascience.com/pandas-join-vs-merge-c365fd4fbf49

# %%
Emp = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})

Grp = pd.DataFrame({'group': ['Accounting', 'Accounting',
                              'Engineering', 'Engineering', 'HR', 'HR'],
                    'skills': ['math', 'spreadsheets', 'coding', 'linux',
                               'spreadsheets', 'organization']})
display( Emp, Grp )
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization

# %%
# Fundindo as duas tabelas
dfm = pd.merge( Emp, Grp, on='group' )   # 'on' é qual coluna usar como key para a combinação
dfm.set_index(['employee'], inplace=True)  # fazer de employee o index
display( dfm )
# Out:
#                 group        skills
# employee
# Bob        Accounting          math
# Bob        Accounting  spreadsheets
# Jake      Engineering        coding
# Jake      Engineering         linux
# Lisa      Engineering        coding
# Lisa      Engineering         linux
# Sue                HR  spreadsheets
# Sue                HR  organization

# %%
print(dfm.loc['Bob','skills'].values)
# Out:
# ['math' 'spreadsheets']

# %% [markdown]
# ### Decidindo o que fazer com dados incompletos
# > `how` = inner, outer, left ou right
#
# Isso é herdado de *databases*

# %%
df6 = pd.DataFrame({'name': ['Peter', 'Paul', 'Mary'],
                    'food': ['fish', 'beans', 'bread']},
                   columns=['name', 'food'])
df7 = pd.DataFrame({'name': ['Mary', 'Joseph'],
                    'drink': ['wine', 'beer']},
                   columns=['name', 'drink'])
display( df6, df7 )
display( pd.merge(df6, df7, on='name') )
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread
#      name drink
# 0    Mary  wine
# 1  Joseph  beer
#    name   food drink
# 0  Mary  bread  wine

# %%
# how
display( pd.merge(df6, df7, on='name', how='inner'), 'Inner merge' )   # Só ficar com os keys que existem nas duas
display( pd.merge(df6, df7, on='name', how='outer'), 'Outer merge' )   # Ficar com todos os keys (e marcar quando falta dado)
display( pd.merge(df6, df7, on='name', how='left'), 'Left merge' )   # Ficar com os keys que aparecem na primeira tabela
display( pd.merge(df6, df7, on='name', how='right'), 'Right merge' )   # Ficar com os keys que aparecem na segunda tabela
# Out:
#    name   food drink
# 0  Mary  bread  wine
# 'Inner merge'
#      name   food drink
# 0   Peter   fish   NaN
# 1    Paul  beans   NaN
# 2    Mary  bread  wine
# 3  Joseph    NaN  beer
# 'Outer merge'
#     name   food drink
# 0  Peter   fish   NaN
# 1   Paul  beans   NaN
# 2   Mary  bread  wine
# 'Left merge'
#      name   food drink
# 0    Mary  bread  wine
# 1  Joseph    NaN  beer
# 'Right merge'

# %% [markdown]
# ## MultiIndex
# https://jakevdp.github.io/PythonDataScienceHandbook/03.05-hierarchical-indexing.html
# https://www.semicolonworld.com/question/53165/select-rows-in-pandas-multiindex-dataframe
# >- for rows and columns

# %%
display( tit.groupby(['Pclass',age_cut,'Sex'])[['Survived']].agg(['mean', 'count']) )
# Out:
#                          Survived
#                              mean count
# Pclass Age       Sex
# 1      (0, 2]    female  0.000000     1
#                  male    1.000000     1
#        (2, 10]   female       NaN     0
#                  male    1.000000     1
#        (10, 18]  female  1.000000    10
#                  male    0.666667     3
#        (18, 30]  female  0.958333    24
#                  male    0.428571    21
#        (30, 40]  female  1.000000    24
#                  male    0.520000    25
#        (40, 60]  female  0.958333    24
#                  male    0.342105    38
#        (60, 100] female  1.000000     2
#                  male    0.083333    12
# 2      (0, 2]    female  1.000000     1
#                  male    1.000000     6
#        (2, 10]   female  1.000000     7
#                  male    1.000000     3
#        (10, 18]  female  1.000000     6
#                  male    0.000000     6
#        (18, 30]  female  0.900000    30
#                  male    0.027027    37
#        (30, 40]  female  0.941176    17
#                  male    0.115385    26
#        (40, 60]  female  0.846154    13
#                  male    0.055556    18
#        (60, 100] female       NaN     0
#                  male    0.333333     3
# 3      (0, 2]    female  0.625000     8
#                  male    0.285714     7
#        (2, 10]   female  0.428571    14
#                  male    0.400000    15
#        (10, 18]  female  0.523810    21
#                  male    0.103448    29
#        (18, 30]  female  0.500000    36
#                  male    0.147541   122
#        (30, 40]  female  0.428571    14
#                  male    0.142857    49
#        (40, 60]  female  0.000000     8
#                  male    0.074074    27
#        (60, 100] female  1.000000     1
#                  male    0.000000     4

# %% [markdown]
# Diego Andrés Laplagne - Instituto do Cérebro, UFRN.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4cebbaee-b9cb-4b8c-9f6a-e0936db7b60a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
